# %%
# Imports
import numpy as np
import pandas as pd
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
import statsmodels.api as sm

# %%
import pandas as pd

# Read the CSV file into a DataFrame
macro = pd.read_csv('HW3/macro.csv', parse_dates=["date"])
topics = pd.read_csv('HW3/topics.csv', parse_dates=["date"])

macro
# Out:
#           date       vol      mret    indpro  indprol1  Agric_vol  Food_vol  \
# 0   1984-01-01 -2.441528 -0.013821  0.019598  0.004659   0.310845  0.095329
# 1   1984-02-01 -2.215468 -0.038863  0.004659  0.004671  -0.081430 -0.002799
# 2   1984-03-01 -2.088957  0.013777  0.004671  0.005914  -0.338281 -0.450892
# 3   1984-04-01 -2.202551  0.002938  0.005914  0.005345   0.317874 -0.537147
# 4   1984-05-01 -2.295892 -0.053505  0.005345  0.003558   0.358976 -0.254617
# ..         ...       ...       ...       ...       ...        ...       ...
# 439 2020-08-01 -1.744960  0.066647  0.009153 -0.000456   1.154092 -0.481345
# 440 2020-09-01 -1.647345 -0.033206 -0.000456  0.006083   0.656901 -0.721287
# 441 2020-10-01 -1.666565 -0.018751  0.006083  0.004420   0.376902 -0.860493
# 442 2020-11-01 -1.606480  0.117764  0.004420  0.011487   0.158031 -0.718061
# 443 2020-12-01 -1.896418  0.044026  0.011487  0.008215  -0.069609 -0.604345
#
#      Soda_vol  Beer_vol  Smoke_vol  ...  Boxes_vol  Trans_vol  Whlsl_vol  \
# 0   -0.032064 -0.026693  -1.039950  ...  -0.501197   0.086025   0.474194
# 1   -0.307625 -0.003307  -0.517003  ...  -0.505793   0.386029   0.502140
# 2   -0.634702  0.225436  -0.398322  ...  -0.241823   0.025585   0.429562
# 3   -1.227010  0.053647  -0.364971  ...  -0.079248   0.376537   0.377819
# 4   -0.697659  0.054901   0.415290  ...  -0.230033   0.311959   0.430125
# ..        ...       ...        ...  ...        ...        ...        ...
# 439 -1.104128 -1.047666  -0.606803  ...  -0.311241  -0.156702   0.284289
# 440 -0.876554 -0.896901  -0.804445  ...  -0.280985   0.011262   0.067576
# 441 -1.265350 -0.976457  -0.313056  ...  -0.111867   0.098630   0.122962
# 442 -1.209639 -1.367155  -0.409594  ...  -0.102082  -0.213766   0.394785
# 443 -1.280351 -1.506372  -0.303915  ...  -0.153341  -0.226562   0.224592
#
#      Rtail_vol  Meals_vol  Banks_vol  Insur_vol  RlEst_vol   Fin_vol  \
# 0     0.560788  -0.656638  -0.158339   0.446504  -0.183200 -0.247725
# 1     0.360408  -0.676141  -0.006122   0.018590  -0.240550 -0.262150
# 2     0.163409  -0.659300   0.090492  -0.014528  -0.242914 -0.317061
# 3     0.010248  -0.743154  -0.064234   0.475832  -0.099469 -0.241596
# 4    -0.465393  -0.679861  -0.063304   0.497335  -0.081488 -0.206172
# ..         ...        ...        ...        ...        ...       ...
# 439  -0.152211  -0.339646   0.438529   0.143031   0.372141 -0.633160
# 440  -0.226658  -0.383983   0.451906   0.198980   0.106599 -0.334079
# 441   0.075485  -0.639138   0.226872   0.141894   0.133778 -0.239778
# 442   0.148036  -1.033340   1.155075   0.300309   0.448229 -0.769945
# 443  -0.035441  -1.019211   1.034391   0.153304   0.151659 -0.726173
#
#      Other_vol
# 0    -0.538995
# 1    -0.473532
# 2    -0.810635
# 3    -0.644135
# 4    -0.555334
# ..         ...
# 439  -0.387497
# 440  -0.299005
# 441  -0.432060
# 442  -0.286702
# 443  -0.405621
#
# [444 rows x 54 columns]
