# %%
# Imports

import pandas as pd
import time
import random
import os
from pytrends.request import TrendReq

# %% [markdown]
# ## Category 1: Loughran-McDonald Dictionary Filtering

# %%
# Read the LM dictionary CSV file into a DataFrame
df = pd.read_csv('Loughran-McDonald_MasterDictionary_1993-2024.csv')

df

df_filtered = df[['Word', 'Negative', 'Positive', 'Uncertainty']]

# Keep only rows where at least one category is nonzero
df_filtered = df_filtered[(df_filtered[['Negative', 'Positive', 'Uncertainty']] != 0).any(axis=1)]

print(len(df_filtered))
df_filtered

print("Negative:", (df_filtered['Negative'] != 0).sum())
print("Positive:", (df_filtered['Positive'] != 0).sum())
print("Uncertainty:", (df_filtered['Uncertainty'] != 0).sum())
# Out:
# 2966
# Negative: 2355
# Positive: 354
# Uncertainty: 297

# %%
# Filter by taking 1 year and removing anything that has 70%+ data =0
# Approximate timing 2-2.5 hours: approx 6 min for 100 keywords

# Settings
TIMEFRAME   = "2023-01-01 2023-12-31"
GEO         = "US"
ZERO_THRESH = 0.70
DELAY       = 15  # increased from 10
BATCH_SIZE  = 5
CHECKPOINT  = "lm_survivors_checkpoint.csv"

# Prep keyword list
keywords = df_filtered['Word'].str.lower().str.strip().unique().tolist()
print(f"Total keywords to test: {len(keywords)}")

batches = [keywords[i:i+BATCH_SIZE] for i in range(0, len(keywords), BATCH_SIZE)]
print(f"Total batches: {len(batches)}")

# ── Resume from checkpoint if it exists ──────────────────────────────────────
if os.path.exists(CHECKPOINT):
    checkpoint_df = pd.read_csv(CHECKPOINT)
    survivors = {row['keyword']: {"zero_pct": row['zero_pct'], "mean_interest": row['mean_interest']} 
                 for _, row in checkpoint_df.iterrows()}
    already_done = set(survivors.keys())
    print(f"Resuming from checkpoint — {len(already_done)} keywords already done")
else:
    survivors = {}
    already_done = set()
    print("Starting fresh")

dropped = []
pytrends = TrendReq(hl="en-US", tz=0, timeout=(10, 30))

for idx, batch in enumerate(batches, 1):
    # Skip batches already completed
    if all(kw in already_done for kw in batch):
        print(f"[{idx}/{len(batches)}] Skipping (already done)")
        continue

    print(f"[{idx}/{len(batches)}] Fetching: {batch}")
    
    success = False
    for attempt in range(1, 4):
        try:
            pytrends.build_payload(batch, timeframe=TIMEFRAME, geo=GEO)
            raw = pytrends.interest_over_time()
            success = True
            break
        except Exception as exc:
            wait = DELAY * (2 ** (attempt - 1)) + random.uniform(0, 3)
            print(f"  Attempt {attempt}/3 failed — {exc}. Retrying in {wait:.1f}s")
            time.sleep(wait)
    
    if not success or raw.empty:
        print(f"  No data — dropping batch")
        dropped.extend(batch)
        continue

    raw = raw.drop(columns=["isPartial"], errors="ignore")

    for kw in batch:
        if kw not in raw.columns:
            dropped.append(kw)
            continue
        series = raw[kw]
        zero_pct = (series == 0).sum() / len(series)
        if zero_pct >= ZERO_THRESH:
            dropped.append(kw)
        else:
            survivors[kw] = {"zero_pct": round(zero_pct, 3), "mean_interest": round(series.mean(), 2)}

    # Save checkpoint every 25 batches
    if idx % 25 == 0:
        pd.DataFrame([{"keyword": kw, **v} for kw, v in survivors.items()]).to_csv(CHECKPOINT, index=False)
        print(f"  ✓ checkpoint saved at batch {idx}")

    if idx < len(batches):
        sleep_time = DELAY + random.uniform(0, DELAY * 0.4)
        time.sleep(sleep_time)

# ── Final save ────────────────────────────────────────────────────────────────
survivors_df = pd.DataFrame([{"keyword": kw, **v} for kw, v in survivors.items()])
survivors_df = survivors_df.sort_values("mean_interest", ascending=False).reset_index(drop=True)
survivors_df.to_csv(CHECKPOINT, index=False)
survivors_df.to_csv("lm_survivors.csv", index=False)

print(f"\nStarted with : {len(keywords)}")
print(f"Survived     : {len(survivors_df)}")
print(f"Dropped      : {len(dropped)}")
survivors_df.head(20)
# Out:
# Total keywords to test: 1833
# Total batches: 367
# Starting fresh
# [1/367] Fetching: ['stock market crash', 'market crash', 'recession', 'bear market', 'financial crisis']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 77
#      75     if idx < len(batches):
#      76         sleep_time = DELAY + random.uniform(0, DELAY * 0.4)
# ---> 77         time.sleep(sleep_time)
#      79 # Final save
#      80 survivors_df = pd.DataFrame([{"keyword": kw, **v} for kw, v in survivors.items()])
#
# KeyboardInterrupt:

# %%
# Filter 1: zero_pct < 0.70 (already done — this is survivors_df)
# Filter 2: mean_interest >= 20
survivors_filtered = survivors_df[survivors_df['mean_interest'] >= 20].reset_index(drop=True)

print(f"After zero filter:     {len(survivors_df)}")
print(f"After interest filter: {len(survivors_filtered)}")
print(f"Dropped by filter 2:   {len(survivors_df) - len(survivors_filtered)}")
survivors_filtered
# Out:
# After zero filter:     2387
# After interest filter: 1035
# Dropped by filter 2:   1352
#            keyword  zero_pct  mean_interest
# 0      corrections       0.0          94.28
# 1        detention       0.0          94.06
# 2          rewards       0.0          92.62
# 3        dangerous       0.0          91.96
# 4           enable       0.0          91.72
# ...            ...       ...            ...
# 1030    sentencing       0.0          20.28
# 1031  interference       0.0          20.21
# 1032        reward       0.0          20.19
# 1033      disagree       0.0          20.15
# 1034       slowing       0.0          20.09
#
# [1035 rows x 3 columns]

# %%
# Finance context filter
# Re-scrape survivors_filtered with "stock market" as anchor in every batch

ANCHOR = "stock market"
keywords_to_retest = survivors_filtered['keyword'].tolist()
batches2 = [keywords_to_retest[i:i+4] for i in range(0, len(keywords_to_retest), 4)]  # 4 per batch to leave room for anchor

print(f"Re-testing {len(keywords_to_retest)} keywords with finance context anchor")
print(f"Total batches: {len(batches2)}")

finance_survivors = {}

for idx, batch in enumerate(batches2, 1):
    batch_with_anchor = batch + [ANCHOR]
    print(f"[{idx}/{len(batches2)}] Fetching: {batch}")
    
    success = False
    for attempt in range(1, 4):
        try:
            pytrends.build_payload(batch_with_anchor, timeframe=TIMEFRAME, geo=GEO)
            raw = pytrends.interest_over_time()
            success = True
            break
        except Exception as exc:
            wait = 15 * (2 ** (attempt - 1)) + random.uniform(0, 3)
            print(f"  Attempt {attempt}/3 failed — {exc}. Retrying in {wait:.1f}s")
            time.sleep(wait)
    
    if not success or raw.empty:
        print(f"  No data — skipping batch")
        continue

    raw = raw.drop(columns=["isPartial"], errors="ignore")

    for kw in batch:
        if kw not in raw.columns:
            continue
        series = raw[kw]
        zero_pct = (series == 0).sum() / len(series)
        if zero_pct >= 0.70:
            print(f"  DROPPED {kw} (not finance-relevant)")
        else:
            finance_survivors[kw] = {
                "zero_pct": round(zero_pct, 3),
                "mean_interest": round(series.mean(), 2)
            }
            print(f"  KEPT {kw} (mean={series.mean():.1f})")

    if idx < len(batches2):
        sleep_time = 15 + random.uniform(0, 6)
        time.sleep(sleep_time)

# Results
finance_survivors_df = pd.DataFrame([{"keyword": kw, **v} for kw, v in finance_survivors.items()])
finance_survivors_df = finance_survivors_df.sort_values("mean_interest", ascending=False).reset_index(drop=True)
finance_survivors_df.to_csv("lm_finance_survivors.csv", index=False)

print(f"\nBefore finance filter: {len(keywords_to_retest)}")
print(f"After finance filter:  {len(finance_survivors_df)}")
finance_survivors_df.head(20)
# Out:
# Re-testing 1035 keywords with finance context anchor
# Total batches: 259
# [1/259] Fetching: ['corrections', 'detention', 'rewards', 'dangerous']
#   KEPT corrections (mean=18.0)
#   KEPT detention (mean=17.5)
#   KEPT rewards (mean=89.6)
#   KEPT dangerous (mean=71.0)
# [2/259] Fetching: ['enable', 'annoying', 'worst', 'accidentally']
#   KEPT enable (mean=35.4)
#   KEPT annoying (mean=11.6)
#   KEPT worst (mean=71.5)
#   KEPT accidentally (mean=17.9)
# [3/259] Fetching: ['superior', 'bad', 'unable', 'termination']
#   KEPT superior (mean=8.3)
#   KEPT bad (mean=92.2)
#   KEPT unable (mean=4.1)
#   KEPT termination (mean=1.1)
# [4/259] Fetching: ['lying', 'cancel', 'annulment', 'great']
#   KEPT lying (mean=5.0)
#   KEPT cancel (mean=21.2)
#   DROPPED annulment (not finance-relevant)
#   KEPT great (mean=89.1)
# [5/259] Fetching: ['claims', 'attractive', 'deficiency', 'weak']
#   KEPT claims (mean=52.1)
#   KEPT attractive (mean=10.6)
#   KEPT deficiency (mean=29.7)
#   KEPT weak (mean=34.9)
# [6/259] Fetching: ['cut', 'abuse', 'strain', 'complaint']
#   KEPT cut (mean=88.2)
#   KEPT abuse (mean=14.4)
#   KEPT strain (mean=23.8)
#   KEPT complaint (mean=6.9)
# [7/259] Fetching: ['error', 'foreclosure', 'abandoned', 'disappointment']
#   KEPT error (mean=89.6)
#   KEPT foreclosure (mean=5.2)
#   KEPT abandoned (mean=11.8)
#   KEPT disappointment (mean=1.0)
# [8/259] Fetching: ['delights', 'problems', 'disclose', 'random']
#   KEPT delights (mean=3.4)
#   KEPT problems (mean=86.6)
#   KEPT disclose (mean=2.0)
#   KEPT random (mean=68.5)
# [9/259] Fetching: ['exposure', 'innovations', 'inappropriate', 'deny']
#   KEPT exposure (mean=30.2)
#   KEPT innovations (mean=9.3)
#   KEPT inappropriate (mean=7.8)
#   KEPT deny (mean=7.1)
# [10/259] Fetching: ['ideal', 'unpaid', 'contractions', 'integrity']
#   KEPT ideal (mean=36.8)
#   KEPT unpaid (mean=4.4)
#   KEPT contractions (mean=10.3)
#   KEPT integrity (mean=19.0)
# [11/259] Fetching: ['crossroads', 'deceased', 'unknown', 'voided']
#   KEPT crossroads (mean=22.0)
#   KEPT deceased (mean=10.6)
#   KEPT unknown (mean=25.0)
#   KEPT voided (mean=1.8)
# [12/259] Fetching: ['exploited', 'enjoy', 'highest', 'misdemeanor']
#   KEPT exploited (mean=1.4)
#   KEPT enjoy (mean=8.8)
#   KEPT highest (mean=81.3)
#   KEPT misdemeanor (mean=4.4)
# [13/259] Fetching: ['easier', 'disturb', 'forced', 'depressed']
#   KEPT easier (mean=18.5)
#   KEPT disturb (mean=8.9)
#   KEPT forced (mean=27.7)
#   KEPT depressed (mean=13.9)
# [14/259] Fetching: ['exclusive', 'invalid', 'kickback', 'counterfeit']
#   KEPT exclusive (mean=21.1)
#   KEPT invalid (mean=11.8)
#   KEPT kickback (mean=3.1)
#   KEPT counterfeit (mean=3.0)
# [15/259] Fetching: ['strong', 'complications', 'terminate', 'denied']
#   KEPT strong (mean=84.9)
#   KEPT complications (mean=7.1)
#   KEPT terminate (mean=3.4)
#   KEPT denied (mean=11.3)
# [16/259] Fetching: ['randomly', 'alliance', 'impressive', 'eviction']
#   KEPT randomly (mean=26.8)
#   KEPT alliance (mean=59.6)
#   KEPT impressive (mean=2.5)
#   KEPT eviction (mean=11.9)
# [17/259] Fetching: ['appear', 'serious', 'delinquent', 'manipulation']
#   KEPT appear (mean=34.8)
#   KEPT serious (mean=26.9)
#   KEPT delinquent (mean=3.6)
#   KEPT manipulation (mean=6.4)
# [18/259] Fetching: ['doubt', 'stress', 'success', 'defeat']
#   KEPT doubt (mean=9.1)
#   KEPT stress (mean=72.2)
#   KEPT success (mean=42.3)
#   KEPT defeat (mean=14.4)
# [19/259] Fetching: ['exploit', 'impediment', 'vibrant', 'prone']
#   KEPT exploit (mean=4.2)
#   KEPT impediment (mean=1.3)
#   KEPT vibrant (mean=5.9)
#   KEPT prone (mean=10.2)
# [20/259] Fetching: ['unavailable', 'revised', 'corruption', 'suspension']
#   KEPT unavailable (mean=10.5)
#   KEPT revised (mean=4.9)
#   KEPT corruption (mean=8.0)
#   KEPT suspension (mean=41.8)
# [21/259] Fetching: ['dangers', 'unattractive', 'strength', 'worse']
#   KEPT dangers (mean=9.8)
#   KEPT unattractive (mean=1.0)
#   KEPT strength (mean=73.9)
#   KEPT worse (mean=42.3)
# [22/259] Fetching: ['litigation', 'enhanced', 'good', 'sacrifice']
#   DROPPED litigation (not finance-relevant)
#   KEPT enhanced (mean=1.0)
#   KEPT good (mean=83.5)
#   KEPT sacrifice (mean=0.7)
# [23/259] Fetching: ['reckless', 'dream', 'questions', 'incarcerated']
#   KEPT reckless (mean=3.0)
#   KEPT dream (mean=80.0)
#   KEPT questions (mean=85.8)
#   KEPT incarcerated (mean=1.3)
# [24/259] Fetching: ['beautiful', 'improve', 'persistent', 'incorrect']
#   KEPT beautiful (mean=81.3)
#   KEPT improve (mean=30.2)
#   KEPT persistent (mean=4.9)
#   KEPT incorrect (mean=5.6)
# [25/259] Fetching: ['progress', 'impaired', 'disappears', 'force']
#   KEPT progress (mean=14.6)
#   KEPT impaired (mean=1.8)
#   KEPT disappears (mean=1.0)
#   KEPT force (mean=82.6)
# [26/259] Fetching: ['lose', 'unemployment', 'embezzlement', 'deviated']
#   KEPT lose (mean=81.8)
#   KEPT unemployment (mean=47.6)
#   KEPT embezzlement (mean=1.0)
#   KEPT deviated (mean=1.7)
# [27/259] Fetching: ['harm', 'crime', 'offender', 'evictions']
#   KEPT harm (mean=11.2)
#   KEPT crime (mean=83.5)
#   KEPT offender (mean=16.3)
#   KEPT evictions (mean=1.0)
# [28/259] Fetching: ['best', 'smooth', 'damage', 'incident']
#   KEPT best (mean=83.4)
#   KEPT smooth (mean=1.0)
#   KEPT damage (mean=2.0)
#   KEPT incident (mean=1.0)
# [29/259] Fetching: ['positive', 'stability', 'could', 'divorce']
#   KEPT positive (mean=64.6)
#   KEPT stability (mean=4.9)
#   KEPT could (mean=81.6)
#   KEPT divorce (mean=45.0)
# [30/259] Fetching: ['innovative', 'problem', 'refusal', 'violation']
#   KEPT innovative (mean=7.6)
#   KEPT problem (mean=82.6)
#   KEPT refusal (mean=2.6)
#   KEPT violation (mean=14.9)
# [31/259] Fetching: ['illegal', 'omit', 'popular', 'inconsistent']
#   KEPT illegal (mean=34.9)
#   KEPT omit (mean=1.0)
#   KEPT popular (mean=82.2)
#   KEPT inconsistent (mean=1.0)
# [32/259] Fetching: ['exacerbation', 'frustrated', 'collaboration', 'incredible']
#   KEPT exacerbation (mean=2.0)
#   KEPT frustrated (mean=3.2)
#   KEPT collaboration (mean=7.5)
#   KEPT incredible (mean=11.9)
# [33/259] Fetching: ['prolonged', 'confused', 'lack', 'cumbersome']
#   KEPT prolonged (mean=4.6)
#   KEPT confused (mean=11.0)
#   KEPT lack (mean=28.0)
#   KEPT cumbersome (mean=1.0)
# [34/259] Fetching: ['satisfaction', 'contingency', 'dispose', 'against']
#   KEPT satisfaction (mean=3.6)
#   KEPT contingency (mean=2.5)
#   KEPT dispose (mean=6.8)
#   KEPT against (mean=81.8)
# [35/259] Fetching: ['delight', 'opportunities', 'unfortunately', 'innovation']
#   KEPT delight (mean=15.6)
#   KEPT opportunities (mean=28.0)
#   KEPT unfortunately (mean=2.7)
#   KEPT innovation (mean=19.0)
# [36/259] Fetching: ['easy', 'inspiration', 'pleasant', 'unsafe']
#   KEPT easy (mean=81.2)
#   KEPT inspiration (mean=2.9)
#   KEPT pleasant (mean=14.9)
#   KEPT unsafe (mean=1.0)
# [37/259] Fetching: ['excellence', 'able', 'slower', 'disappointed']
#   KEPT excellence (mean=12.2)
#   KEPT able (mean=69.3)
#   KEPT slower (mean=6.4)
#   KEPT disappointed (mean=2.7)
# [38/259] Fetching: ['aberration', 'valuable', 'confiscated', 'benefit']
#   KEPT aberration (mean=1.4)
#   KEPT valuable (mean=14.9)
#   KEPT confiscated (mean=1.0)
#   KEPT benefit (mean=62.0)
# [39/259] Fetching: ['disciplinary', 'rejection', 'fantastic', 'destruction']
#   KEPT disciplinary (mean=2.5)
#   KEPT rejection (mean=6.7)
#   KEPT fantastic (mean=22.8)
#   KEPT destruction (mean=11.5)
# [40/259] Fetching: ['overcoming', 'succeed', 'malpractice', 'negligence']
#   KEPT overcoming (mean=2.7)
#   KEPT succeed (mean=4.3)
#   KEPT malpractice (mean=7.1)
#   KEPT negligence (mean=4.5)
# [41/259] Fetching: ['late', 'overage', 'unpopular', 'obsolete']
#   KEPT late (mean=83.3)
#   DROPPED overage (not finance-relevant)
#   KEPT unpopular (mean=1.0)
#   KEPT obsolete (mean=1.9)
# [42/259] Fetching: ['favorite', 'breaking', 'difficult', 'mismatch']
#   KEPT favorite (mean=37.6)
#   KEPT breaking (mean=80.3)
#   KEPT difficult (mean=17.4)
#   KEPT mismatch (mean=1.6)
# [43/259] Fetching: ['subpoena', 'slow', 'collision', 'overload']
#   KEPT subpoena (mean=3.0)
#   KEPT slow (mean=79.8)
#   KEPT collision (mean=27.6)
#   KEPT overload (mean=4.6)
# [44/259] Fetching: ['nuisance', 'mistake', 'assured', 'sue']
#   KEPT nuisance (mean=2.2)
#   KEPT mistake (mean=10.4)
#   KEPT assured (mean=2.6)
#   KEPT sue (mean=43.6)
# [45/259] Fetching: ['irregular', 'disregard', 'inevitable', 'fraud']
#   KEPT irregular (mean=11.6)
#   KEPT disregard (mean=1.6)
#   KEPT inevitable (mean=2.8)
#   KEPT fraud (mean=37.3)
# [46/259] Fetching: ['discrepancy', 'exposures', 'unexpected', 'believe']
#   KEPT discrepancy (mean=2.6)
#   KEPT exposures (mean=1.0)
#   KEPT unexpected (mean=8.8)
#   KEPT believe (mean=64.5)
# [47/259] Fetching: ['resolve', 'reassess', 'deprivation', 'inspirational']
#   KEPT resolve (mean=18.0)
#   DROPPED reassess (not finance-relevant)
#   KEPT deprivation (mean=4.3)
#   KEPT inspirational (mean=16.1)
# [48/259] Fetching: ['creative', 'dissolution', 'enhancing', 'obstacle']
#   KEPT creative (mean=65.4)
#   KEPT dissolution (mean=3.3)
#   KEPT enhancing (mean=2.9)
#   KEPT obstacle (mean=5.0)
# [49/259] Fetching: ['precautions', 'advantage', 'bankruptcy', 'imbalance']
#   KEPT precautions (mean=6.8)
#   KEPT advantage (mean=67.8)
#   KEPT bankruptcy (mean=22.8)
#   KEPT imbalance (mean=6.0)
# [50/259] Fetching: ['vulnerability', 'abruptly', 'default', 'wrong']
#   KEPT vulnerability (mean=4.1)
#   KEPT abruptly (mean=1.0)
#   KEPT default (mean=41.2)
#   KEPT wrong (mean=78.8)
# [51/259] Fetching: ['prejudice', 'limitations', 'anomaly', 'friendly']
#   KEPT prejudice (mean=10.7)
#   KEPT limitations (mean=9.6)
#   KEPT anomaly (mean=3.8)
#   KEPT friendly (mean=77.7)
# [52/259] Fetching: ['efficient', 'absence', 'seems', 'overcharge']
#   KEPT efficient (mean=15.2)
#   KEPT absence (mean=12.1)
#   KEPT seems (mean=11.2)
#   KEPT overcharge (mean=1.0)
# [53/259] Fetching: ['terminated', 'tense', 'hurt', 'misappropriation']
#   KEPT terminated (mean=2.0)
#   KEPT tense (mean=10.9)
#   KEPT hurt (mean=83.2)
#   DROPPED misappropriation (not finance-relevant)
# [54/259] Fetching: ['misrepresentation', 'harmful', 'improving', 'bridge']
#   DROPPED misrepresentation (not finance-relevant)
#   KEPT harmful (mean=6.3)
#   KEPT improving (mean=2.6)
#   KEPT bridge (mean=77.1)
# [55/259] Fetching: ['unusual', 'impairment', 'collaborate', 'evasion']
#   KEPT unusual (mean=9.7)
#   KEPT impairment (mean=4.5)
#   KEPT collaborate (mean=2.6)
#   KEPT evasion (mean=2.9)
# [56/259] Fetching: ['objection', 'punishment', 'negative', 'contentious']
#   KEPT objection (mean=1.4)
#   KEPT punishment (mean=11.6)
#   KEPT negative (mean=76.0)
#   KEPT contentious (mean=1.0)
# [57/259] Fetching: ['divestiture', 'wrongly', 'decline', 'fallout']
#   DROPPED divestiture (not finance-relevant)
#   KEPT wrongly (mean=1.0)
#   KEPT decline (mean=15.4)
#   KEPT fallout (mean=73.5)
# [58/259] Fetching: ['defend', 'deterioration', 'liquidators', 'failed']
#   KEPT defend (mean=7.0)
#   KEPT deterioration (mean=1.0)
#   KEPT liquidators (mean=4.6)
#   KEPT failed (mean=42.5)
# [59/259] Fetching: ['disclosed', 'degradation', 'uncontrolled', 'empower']
#   KEPT disclosed (mean=1.0)
#   KEPT degradation (mean=2.5)
#   KEPT uncontrolled (mean=1.9)
#   KEPT empower (mean=19.1)
# [60/259] Fetching: ['trouble', 'dispossessed', 'unfit', 'conditional']
#   KEPT trouble (mean=49.1)
#   DROPPED dispossessed (not finance-relevant)
#   KEPT unfit (mean=0.9)
#   KEPT conditional (mean=11.9)
# [61/259] Fetching: ['worthy', 'firing', 'infringement', 'disastrous']
#   KEPT worthy (mean=8.3)
#   KEPT firing (mean=15.5)
#   KEPT infringement (mean=2.0)
#   KEPT disastrous (mean=0.9)
# [62/259] Fetching: ['understatement', 'redress', 'satisfy', 'efficiency']
#   KEPT understatement (mean=1.0)
#   KEPT redress (mean=1.8)
#   KEPT satisfy (mean=3.2)
#   KEPT efficiency (mean=14.8)
# [63/259] Fetching: ['fear', 'violence', 'lag', 'complaints']
#   KEPT fear (mean=73.6)
#   KEPT violence (mean=32.6)
#   KEPT lag (mean=12.6)
#   KEPT complaints (mean=19.4)
# [64/259] Fetching: ['unsure', 'rebound', 'confess', 'unfortunate']
#   KEPT unsure (mean=1.4)
#   KEPT rebound (mean=7.2)
#   KEPT confess (mean=3.8)
#   KEPT unfortunate (mean=4.4)
# [65/259] Fetching: ['restructuring', 'sever', 'distress', 'misconduct']
#   KEPT restructuring (mean=1.3)
#   KEPT sever (mean=3.7)
#   KEPT distress (mean=8.0)
#   KEPT misconduct (mean=3.3)
# [66/259] Fetching: ['exacerbate', 'resignation', 'unproductive', 'contempt']
#   KEPT exacerbate (mean=1.3)
#   KEPT resignation (mean=9.1)
#   DROPPED unproductive (not finance-relevant)
#   KEPT contempt (mean=5.2)
# [67/259] Fetching: ['destroy', 'alterations', 'disagreement', 'depends']
#   KEPT destroy (mean=23.3)
#   KEPT alterations (mean=10.1)
#   KEPT disagreement (mean=1.6)
#   KEPT depends (mean=7.2)
# [68/259] Fetching: ['challenges', 'detrimental', 'invalidate', 'undefined']
#   KEPT challenges (mean=23.2)
#   KEPT detrimental (mean=2.1)
#   KEPT invalidate (mean=0.8)
#   KEPT undefined (mean=4.9)
# [69/259] Fetching: ['distinction', 'undermine', 'underestimate', 'guilty']
#   KEPT distinction (mean=3.1)
#   KEPT undermine (mean=1.6)
#   KEPT underestimate (mean=1.0)
#   KEPT guilty (mean=23.4)
# [70/259] Fetching: ['question', 'embarrassed', 'dismissed', 'overturned']
#   KEPT question (mean=73.0)
#   KEPT embarrassed (mean=2.4)
#   KEPT dismissed (mean=2.9)
#   KEPT overturned (mean=2.1)
# [71/259] Fetching: ['achieve', 'alienation', 'overpayment', 'concern']
#   KEPT achieve (mean=16.1)
#   KEPT alienation (mean=1.7)
#   KEPT overpayment (mean=1.7)
#   KEPT concern (mean=11.7)
# [72/259] Fetching: ['oversupply', 'discrepancies', 'despite', 'advantages']
#   DROPPED oversupply (not finance-relevant)
#   KEPT discrepancies (mean=0.9)
#   KEPT despite (mean=7.5)
#   KEPT advantages (mean=18.0)
# [73/259] Fetching: ['accidents', 'preclude', 'overlook', 'perfect']
#   KEPT accidents (mean=7.2)
#   KEPT preclude (mean=0.5)
#   KEPT overlook (mean=4.5)
#   KEPT perfect (mean=70.2)
# [74/259] Fetching: ['urgent', 'punished', 'hazard', 'tragedies']
#   KEPT urgent (mean=71.8)
#   KEPT punished (mean=1.5)
#   KEPT hazard (mean=8.5)
#   KEPT tragedies (mean=0.5)
# [75/259] Fetching: ['uncontrollable', 'controversial', 'distinctive', 'risk']
#   KEPT uncontrollable (mean=1.0)
#   KEPT controversial (mean=5.8)
#   KEPT distinctive (mean=1.7)
#   KEPT risk (mean=71.1)
# [76/259] Fetching: ['inadequate', 'unjust', 'opportunity', 'contention']
#   KEPT inadequate (mean=2.2)
#   KEPT unjust (mean=1.6)
#   KEPT opportunity (mean=24.7)
#   KEPT contention (mean=1.4)
# [77/259] Fetching: ['solving', 'unfamiliar', 'deception', 'overcome']
#   KEPT solving (mean=13.8)
#   KEPT unfamiliar (mean=1.2)
#   KEPT deception (mean=5.4)
#   KEPT overcome (mean=8.2)
# [78/259] Fetching: ['missed', 'reassign', 'imperative', 'diligent']
#   KEPT missed (mean=23.8)
#   DROPPED reassign (not finance-relevant)
#   KEPT imperative (mean=3.7)
#   KEPT diligent (mean=2.6)
# [79/259] Fetching: ['investigation', 'might', 'inferior', 'critical']
#   KEPT investigation (mean=18.9)
#   KEPT might (mean=65.6)
#   KEPT inferior (mean=7.6)
#   KEPT critical (mean=45.8)
# [80/259] Fetching: ['concerned', 'diminished', 'improper', 'culpable']
#   KEPT concerned (mean=11.3)
#   KEPT diminished (mean=2.6)
#   KEPT improper (mean=5.2)
#   KEPT culpable (mean=1.0)
# [81/259] Fetching: ['slowly', 'stopped', 'disparaging', 'liquidation']
#   KEPT slowly (mean=10.5)
#   KEPT stopped (mean=32.3)
#   KEPT disparaging (mean=0.8)
#   KEPT liquidation (mean=8.0)
# [82/259] Fetching: ['inefficient', 'discouraged', 'encouraging', 'demolition']
#   KEPT inefficient (mean=0.8)
#   KEPT discouraged (mean=1.1)
#   KEPT encouraging (mean=5.6)
#   KEPT demolition (mean=7.5)
# [83/259] Fetching: ['suspicious', 'neglect', 'sometimes', 'discourage']
#   KEPT suspicious (mean=7.0)
#   KEPT neglect (mean=6.1)
#   KEPT sometimes (mean=29.7)
#   KEPT discourage (mean=1.1)
# [84/259] Fetching: ['criticism', 'penalties', 'closed', 'redacted']
#   KEPT criticism (mean=4.4)
#   KEPT penalties (mean=3.7)
#   KEPT closed (mean=70.2)
#   KEPT redacted (mean=1.2)
# [85/259] Fetching: ['disadvantages', 'advancement', 'inability', 'argument']
#   KEPT disadvantages (mean=11.4)
#   KEPT advancement (mean=4.6)
#   KEPT inability (mean=2.9)
#   KEPT argument (mean=22.6)
# [86/259] Fetching: ['unmatched', 'corrupt', 'erosion', 'circumvent']
#   KEPT unmatched (mean=1.0)
#   KEPT corrupt (mean=6.6)
#   KEPT erosion (mean=8.2)
#   KEPT circumvent (mean=1.0)
# [87/259] Fetching: ['unreliable', 'improvements', 'curtail', 'prevention']
#   KEPT unreliable (mean=1.5)
#   KEPT improvements (mean=5.6)
#   KEPT curtail (mean=0.5)
#   KEPT prevention (mean=26.3)
# [88/259] Fetching: ['disgrace', 'incomplete', 'contradict', 'premiere']
#   KEPT disgrace (mean=1.0)
#   KEPT incomplete (mean=6.1)
#   KEPT contradict (mean=1.5)
#   KEPT premiere (mean=33.3)
# [89/259] Fetching: ['intermittent', 'disapprove', 'stable', 'drag']
#   KEPT intermittent (mean=20.6)
#   DROPPED disapprove (not finance-relevant)
#   KEPT stable (mean=30.0)
#   KEPT drag (mean=62.4)
# [90/259] Fetching: ['derogatory', 'disloyal', 'advances', 'displaced']
#   KEPT derogatory (mean=2.7)
#   DROPPED disloyal (not finance-relevant)
#   KEPT advances (mean=4.6)
#   KEPT displaced (mean=3.0)
# [91/259] Fetching: ['scrutiny', 'untenable', 'arbitrary', 'stolen']
#   KEPT scrutiny (mean=1.5)
#   KEPT untenable (mean=0.8)
#   KEPT arbitrary (mean=2.9)
#   KEPT stolen (mean=31.0)
# [92/259] Fetching: ['disruptive', 'ingenuity', 'renounce', 'idle']
#   KEPT disruptive (mean=2.5)
#   KEPT ingenuity (mean=2.7)
#   KEPT renounce (mean=1.0)
#   KEPT idle (mean=28.7)
# [93/259] Fetching: ['susceptible', 'underperforming', 'approximately', 'disrupt']
#   KEPT susceptible (mean=3.2)
#   DROPPED underperforming (not finance-relevant)
#   KEPT approximately (mean=13.1)
#   KEPT disrupt (mean=2.3)
# [94/259] Fetching: ['depend', 'misinterpreted', 'evade', 'confronted']
#   KEPT depend (mean=5.2)
#   DROPPED misinterpreted (not finance-relevant)
#   KEPT evade (mean=2.0)
#   KEPT confronted (mean=0.9)
# [95/259] Fetching: ['burned', 'inventor', 'anomalies', 'confession']
#   KEPT burned (mean=21.2)
#   KEPT inventor (mean=9.5)
#   KEPT anomalies (mean=1.0)
#   KEPT confession (mean=6.6)
# [96/259] Fetching: ['encouragement', 'conflicts', 'break', 'spam']
#   KEPT encouragement (mean=1.8)
#   KEPT conflicts (mean=1.8)
#   KEPT break (mean=67.8)
#   KEPT spam (mean=8.4)
# [97/259] Fetching: ['false', 'loss', 'adequately', 'undesirable']
#   KEPT false (mean=22.3)
#   KEPT loss (mean=86.1)
#   DROPPED adequately (not finance-relevant)
#   DROPPED undesirable (not finance-relevant)
# [98/259] Fetching: ['speculation', 'failure', 'win', 'boost']
#   KEPT speculation (mean=0.5)
#   KEPT failure (mean=24.8)
#   KEPT win (mean=65.8)
#   KEPT boost (mean=34.2)
# [99/259] Fetching: ['crisis', 'seriously', 'warnings', 'rejected']
#   KEPT crisis (mean=43.5)
#   KEPT seriously (mean=3.3)
#   KEPT warnings (mean=6.5)
#   KEPT rejected (mean=7.9)
# [100/259] Fetching: ['distortion', 'bail', 'deterrent', 'conclusive']
#   KEPT distortion (mean=4.5)
#   KEPT bail (mean=17.2)
#   KEPT deterrent (mean=3.4)
#   DROPPED conclusive (not finance-relevant)
# [101/259] Fetching: ['leadership', 'inactivity', 'unrecoverable', 'rebounding']
#   KEPT leadership (mean=52.6)
#   KEPT inactivity (mean=1.0)
#   DROPPED unrecoverable (not finance-relevant)
#   KEPT rebounding (mean=0.9)
# [102/259] Fetching: ['concede', 'mismanagement', 'opposition', 'fluctuations']
#   KEPT concede (mean=1.0)
#   DROPPED mismanagement (not finance-relevant)
#   KEPT opposition (mean=4.2)
#   KEPT fluctuations (mean=1.1)
# [103/259] Fetching: ['dysfunction', 'immature', 'disappeared', 'contradiction']
#   KEPT dysfunction (mean=14.1)
#   KEPT immature (mean=4.2)
#   KEPT disappeared (mean=10.7)
#   KEPT contradiction (mean=1.4)
# [104/259] Fetching: ['stabilize', 'misleading', 'achieving', 'pervasive']
#   KEPT stabilize (mean=2.2)
#   KEPT misleading (mean=1.3)
#   KEPT achieving (mean=2.9)
#   KEPT pervasive (mean=1.6)
# [105/259] Fetching: ['distorted', 'lost', 'probability', 'corrupted']
#   KEPT distorted (mean=0.9)
#   KEPT lost (mean=63.0)
#   KEPT probability (mean=6.3)
#   KEPT corrupted (mean=1.8)
# [106/259] Fetching: ['suggest', 'defunct', 'mischief', 'cease']
#   KEPT suggest (mean=10.2)
#   KEPT defunct (mean=1.0)
#   KEPT mischief (mean=3.3)
#   KEPT cease (mean=5.5)
# [107/259] Fetching: ['differ', 'invented', 'impede', 'enhance']
#   KEPT differ (mean=15.0)
#   KEPT invented (mean=64.0)
#   KEPT impede (mean=1.0)
#   KEPT enhance (mean=9.1)
# [108/259] Fetching: ['disruption', 'discontinuing', 'weakness', 'omission']
#   KEPT disruption (mean=2.4)
#   KEPT discontinuing (mean=1.0)
#   KEPT weakness (mean=39.1)
#   KEPT omission (mean=1.1)
# [109/259] Fetching: ['prediction', 'controversy', 'honor', 'greatly']
#   KEPT prediction (mean=56.9)
#   KEPT controversy (mean=27.3)
#   KEPT honor (mean=53.5)
#   KEPT greatly (mean=3.4)
# [110/259] Fetching: ['dispute', 'unnecessary', 'cyberbullying', 'demise']
#   KEPT dispute (mean=16.6)
#   KEPT unnecessary (mean=2.8)
#   KEPT cyberbullying (mean=1.6)
#   KEPT demise (mean=2.4)
# [111/259] Fetching: ['tragedy', 'omitted', 'petty', 'premier']
#   KEPT tragedy (mean=2.8)
#   DROPPED omitted (not finance-relevant)
#   KEPT petty (mean=5.6)
#   KEPT premier (mean=62.0)
# [112/259] Fetching: ['reject', 'counterfeiting', 'disadvantage', 'infraction']
#   KEPT reject (mean=7.5)
#   DROPPED counterfeiting (not finance-relevant)
#   KEPT disadvantage (mean=4.6)
#   KEPT infraction (mean=1.7)
# [113/259] Fetching: ['noncompliance', 'predict', 'repudiate', 'refuse']
#   DROPPED noncompliance (not finance-relevant)
#   KEPT predict (mean=11.2)
#   DROPPED repudiate (not finance-relevant)
#   KEPT refuse (mean=11.1)
# [114/259] Fetching: ['variable', 'assume', 'fluctuating', 'allegations']
#   KEPT variable (mean=57.5)
#   KEPT assume (mean=14.6)
#   KEPT fluctuating (mean=1.0)
#   KEPT allegations (mean=6.2)
# [115/259] Fetching: ['distressed', 'misuse', 'complain', 'achievement']
#   KEPT distressed (mean=6.4)
#   KEPT misuse (mean=1.6)
#   KEPT complain (mean=5.2)
#   KEPT achievement (mean=13.8)
# [116/259] Fetching: ['aberrant', 'concealed', 'contraction', 'perpetrated']
#   KEPT aberrant (mean=1.0)
#   KEPT concealed (mean=16.2)
#   KEPT contraction (mean=7.4)
#   DROPPED perpetrated (not finance-relevant)
# [117/259] Fetching: ['nonpayment', 'accident', 'revolutionized', 'stagnation']
#   DROPPED nonpayment (not finance-relevant)
#   KEPT accident (mean=60.4)
#   DROPPED revolutionized (not finance-relevant)
#   DROPPED stagnation (not finance-relevant)
# [118/259] Fetching: ['suggested', 'upset', 'delay', 'tentative']
#   KEPT suggested (mean=7.2)
#   KEPT upset (mean=24.2)
#   KEPT delay (mean=28.2)
#   KEPT tentative (mean=3.0)
# [119/259] Fetching: ['dependent', 'overstated', 'discontinued', 'inactivated']
#   KEPT dependent (mean=27.8)
#   DROPPED overstated (not finance-relevant)
#   KEPT discontinued (mean=20.8)
#   DROPPED inactivated (not finance-relevant)
# [120/259] Fetching: ['fault', 'misinterpretation', 'cancelled', 'misinterpret']
#   KEPT fault (mean=30.3)
#   DROPPED misinterpretation (not finance-relevant)
#   KEPT cancelled (mean=40.4)
#   DROPPED misinterpret (not finance-relevant)
# [121/259] Fetching: ['unclear', 'undetectable', 'implicated', 'confident']
#   KEPT unclear (mean=1.0)
#   KEPT undetectable (mean=1.4)
#   KEPT implicated (mean=0.5)
#   KEPT confident (mean=5.8)
# [122/259] Fetching: ['irreversible', 'compliment', 'hidden', 'greatness']
#   KEPT irreversible (mean=1.1)
#   KEPT compliment (mean=5.5)
#   KEPT hidden (mean=84.5)
#   KEPT greatness (mean=3.0)
# [123/259] Fetching: ['retaliation', 'encroachment', 'misunderstood', 'confronting']
#   KEPT retaliation (mean=3.1)
#   KEPT encroachment (mean=1.0)
#   KEPT misunderstood (mean=1.4)
#   KEPT confronting (mean=1.0)
# [124/259] Fetching: ['impractical', 'disappear', 'disaster', 'rationalize']
#   KEPT impractical (mean=7.0)
#   KEPT disappear (mean=9.9)
#   KEPT disaster (mean=24.2)
#   KEPT rationalize (mean=0.7)
# [125/259] Fetching: ['achievements', 'careless', 'regaining', 'unconscionable']
#   KEPT achievements (mean=13.3)
#   KEPT careless (mean=3.0)
#   DROPPED regaining (not finance-relevant)
#   DROPPED unconscionable (not finance-relevant)
# [126/259] Fetching: ['happy', 'regained', 'demoted', 'sudden']
#   KEPT happy (mean=58.8)
#   DROPPED regained (not finance-relevant)
#   DROPPED demoted (not finance-relevant)
#   KEPT sudden (mean=5.1)
# [127/259] Fetching: ['unreasonably', 'predictor', 'disparities', 'distracted']
#   DROPPED unreasonably (not finance-relevant)
#   KEPT predictor (mean=6.2)
#   KEPT disparities (mean=2.6)
#   KEPT distracted (mean=2.5)
# [128/259] Fetching: ['encumbrance', 'uncertainty', 'alerting', 'defensive']
#   KEPT encumbrance (mean=0.9)
#   KEPT uncertainty (mean=3.6)
#   KEPT alerting (mean=1.0)
#   KEPT defensive (mean=19.4)
# [129/259] Fetching: ['redaction', 'recession', 'misinformation', 'cancels']
#   DROPPED redaction (not finance-relevant)
#   KEPT recession (mean=12.2)
#   KEPT misinformation (mean=1.7)
#   KEPT cancels (mean=2.8)
# [130/259] Fetching: ['illicit', 'conspiracy', 'concerns', 'mistakes']
#   KEPT illicit (mean=2.9)
#   KEPT conspiracy (mean=15.4)
#   KEPT concerns (mean=9.0)
#   KEPT mistakes (mean=7.6)
# [131/259] Fetching: ['suffering', 'harassment', 'dismissal', 'wasted']
#   KEPT suffering (mean=8.8)
#   KEPT harassment (mean=10.8)
#   KEPT dismissal (mean=3.5)
#   KEPT wasted (mean=5.5)
# [132/259] Fetching: ['satisfactory', 'exclusives', 'exposed', 'spectacular']
#   KEPT satisfactory (mean=4.6)
#   KEPT exclusives (mean=2.6)
#   KEPT exposed (mean=19.6)
#   KEPT spectacular (mean=4.9)
# [133/259] Fetching: ['embargo', 'disclaimer', 'suggests', 'enthusiasm']
#   KEPT embargo (mean=3.5)
#   KEPT disclaimer (mean=2.2)
#   KEPT suggests (mean=6.6)
#   KEPT enthusiasm (mean=5.8)
# [134/259] Fetching: ['fail', 'exaggerated', 'endangered', 'deviation']
#   KEPT fail (mean=31.3)
#   KEPT exaggerated (mean=1.3)
#   KEPT endangered (mean=9.8)
#   KEPT deviation (mean=20.5)
# [135/259] Fetching: ['broken', 'overproduction', 'obstacles', 'relinquished']
#   KEPT broken (mean=92.7)
#   KEPT overproduction (mean=0.4)
#   KEPT obstacles (mean=2.4)
#   DROPPED relinquished (not finance-relevant)
# [136/259] Fetching: ['collusion', 'opposing', 'anomalous', 'disqualify']
#   KEPT collusion (mean=1.1)
#   KEPT opposing (mean=3.4)
#   KEPT anomalous (mean=1.0)
#   KEPT disqualify (mean=1.0)
# [137/259] Fetching: ['suspended', 'challenge', 'nonconformity', 'embarrassing']
#   KEPT suspended (mean=11.4)
#   KEPT challenge (mean=55.9)
#   DROPPED nonconformity (not finance-relevant)
#   KEPT embarrassing (mean=1.1)
# [138/259] Fetching: ['negatively', 'disclosing', 'dishonored', 'nullification']
#   KEPT negatively (mean=4.7)
#   KEPT disclosing (mean=1.0)
#   KEPT dishonored (mean=2.6)
#   KEPT nullification (mean=1.7)
# [139/259] Fetching: ['enhancement', 'apparent', 'defamatory', 'reassessment']
#   KEPT enhancement (mean=7.8)
#   KEPT apparent (mean=3.3)
#   DROPPED defamatory (not finance-relevant)
#   DROPPED reassessment (not finance-relevant)
# [140/259] Fetching: ['abrupt', 'criminal', 'excellent', 'satisfying']
#   KEPT abrupt (mean=1.0)
#   KEPT criminal (mean=73.7)
#   KEPT excellent (mean=7.8)
#   KEPT satisfying (mean=2.3)
# [141/259] Fetching: ['unintentional', 'vague', 'successful', 'interrupted']
#   KEPT unintentional (mean=1.1)
#   KEPT vague (mean=2.8)
#   KEPT successful (mean=26.6)
#   KEPT interrupted (mean=3.9)
# [142/259] Fetching: ['poor', 'optimistic', 'defame', 'recall']
#   KEPT poor (mean=42.5)
#   KEPT optimistic (mean=2.8)
#   DROPPED defame (not finance-relevant)
#   KEPT recall (mean=51.8)
# [143/259] Fetching: ['defendant', 'incapacitated', 'incarceration', 'attain']
#   KEPT defendant (mean=4.8)
#   KEPT incapacitated (mean=1.0)
#   KEPT incarceration (mean=2.4)
#   KEPT attain (mean=1.6)
# [144/259] Fetching: ['disparity', 'incompetent', 'falsification', 'downward']
#   KEPT disparity (mean=2.4)
#   KEPT incompetent (mean=2.0)
#   DROPPED falsification (not finance-relevant)
#   KEPT downward (mean=4.3)
# [145/259] Fetching: ['rumors', 'speculative', 'disallowed', 'unintended']
#   KEPT rumors (mean=51.9)
#   KEPT speculative (mean=1.0)
#   DROPPED disallowed (not finance-relevant)
#   KEPT unintended (mean=0.9)
# [146/259] Fetching: ['possible', 'volatile', 'reluctant', 'dismiss']
#   KEPT possible (mean=78.3)
#   KEPT volatile (mean=3.6)
#   KEPT reluctant (mean=3.7)
#   KEPT dismiss (mean=3.1)
# [147/259] Fetching: ['conciliation', 'undocumented', 'undercut', 'risking']
#   DROPPED conciliation (not finance-relevant)
#   KEPT undocumented (mean=2.8)
#   KEPT undercut (mean=3.4)
#   DROPPED risking (not finance-relevant)
# [148/259] Fetching: ['inquiry', 'perhaps', 'falsified', 'antitrust']
#   KEPT inquiry (mean=10.9)
#   KEPT perhaps (mean=3.8)
#   DROPPED falsified (not finance-relevant)
#   KEPT antitrust (mean=3.2)
# [149/259] Fetching: ['difficulty', 'opportunistic', 'desired', 'disturbed']
#   KEPT difficulty (mean=17.2)
#   KEPT opportunistic (mean=0.9)
#   KEPT desired (mean=5.4)
#   KEPT disturbed (mean=5.3)
# [150/259] Fetching: ['conceded', 'malice', 'nonconforming', 'nonproductive']
#   KEPT conceded (mean=0.9)
#   KEPT malice (mean=4.5)
#   DROPPED nonconforming (not finance-relevant)
#   DROPPED nonproductive (not finance-relevant)
# [151/259] Fetching: ['panic', 'dishonest', 'grievance', 'fluctuation']
#   KEPT panic (mean=27.6)
#   KEPT dishonest (mean=0.9)
#   KEPT grievance (mean=2.7)
#   KEPT fluctuation (mean=1.0)
# [152/259] Fetching: ['distraction', 'inventions', 'restatement', 'defamation']
#   KEPT distraction (mean=2.1)
#   KEPT inventions (mean=7.0)
#   KEPT restatement (mean=0.7)
#   KEPT defamation (mean=4.2)
# [153/259] Fetching: ['confronts', 'unpredictable', 'versatile', 'overburden']
#   KEPT confronts (mean=0.8)
#   KEPT unpredictable (mean=1.0)
#   KEPT versatile (mean=3.3)
#   DROPPED overburden (not finance-relevant)
# [154/259] Fetching: ['dissenting', 'overshadow', 'closing', 'denial']
#   KEPT dissenting (mean=0.7)
#   DROPPED overshadow (not finance-relevant)
#   KEPT closing (mean=66.4)
#   KEPT denial (mean=6.9)
# [155/259] Fetching: ['manipulate', 'incompatible', 'prosecution', 'ineligible']
#   KEPT manipulate (mean=3.6)
#   KEPT incompatible (mean=1.9)
#   KEPT prosecution (mean=2.6)
#   KEPT ineligible (mean=1.2)
# [156/259] Fetching: ['exploitation', 'overshadowed', 'deadweight', 'confiscate']
#   KEPT exploitation (mean=2.5)
#   DROPPED overshadowed (not finance-relevant)
#   KEPT deadweight (mean=0.5)
#   DROPPED confiscate (not finance-relevant)
# [157/259] Fetching: ['divestment', 'usury', 'noncompetitive', 'exploits']
#   DROPPED divestment (not finance-relevant)
#   KEPT usury (mean=1.0)
#   DROPPED noncompetitive (not finance-relevant)
#   KEPT exploits (mean=1.2)
# [158/259] Fetching: ['encumbered', 'exclusively', 'contingent', 'suffer']
#   KEPT encumbered (mean=0.4)
#   KEPT exclusively (mean=2.4)
#   KEPT contingent (mean=5.7)
#   KEPT suffer (mean=7.5)
# [159/259] Fetching: ['transparency', 'underperform', 'degrade', 'riskier']
#   KEPT transparency (mean=6.4)
#   DROPPED underperform (not finance-relevant)
#   KEPT degrade (mean=1.4)
#   DROPPED riskier (not finance-relevant)
# [160/259] Fetching: ['protesting', 'lie', 'approximation', 'defects']
#   KEPT protesting (mean=1.9)
#   KEPT lie (mean=37.0)
#   KEPT approximation (mean=2.0)
#   KEPT defects (mean=4.4)
# [161/259] Fetching: ['monopolistic', 'correction', 'overrun', 'nullify']
#   KEPT monopolistic (mean=1.2)
#   KEPT correction (mean=9.9)
#   KEPT overrun (mean=0.8)
#   KEPT nullify (mean=0.8)
# [162/259] Fetching: ['impress', 'impressed', 'untruthful', 'shortage']
#   KEPT impress (mean=4.6)
#   KEPT impressed (mean=1.3)
#   DROPPED untruthful (not finance-relevant)
#   KEPT shortage (mean=20.0)
# [163/259] Fetching: ['improvement', 'illegally', 'worry', 'misstep']
#   KEPT improvement (mean=25.9)
#   KEPT illegally (mean=2.3)
#   KEPT worry (mean=23.3)
#   DROPPED misstep (not finance-relevant)
# [164/259] Fetching: ['displacement', 'suing', 'unsuccessful', 'unwanted']
#   KEPT displacement (mean=6.9)
#   KEPT suing (mean=5.4)
#   KEPT unsuccessful (mean=1.5)
#   KEPT unwanted (mean=5.8)
# [165/259] Fetching: ['declining', 'breach', 'constructive', 'curtailment']
#   KEPT declining (mean=3.9)
#   KEPT breach (mean=20.8)
#   KEPT constructive (mean=3.2)
#   DROPPED curtailment (not finance-relevant)
# [166/259] Fetching: ['almost', 'influential', 'deteriorating', 'exacerbated']
#   KEPT almost (mean=31.6)
#   KEPT influential (mean=4.8)
#   KEPT deteriorating (mean=0.9)
#   KEPT exacerbated (mean=1.0)
# [167/259] Fetching: ['prestige', 'victims', 'stabilized', 'unreasonable']
#   KEPT prestige (mean=21.8)
#   KEPT victims (mean=19.4)
#   KEPT stabilized (mean=1.3)
#   KEPT unreasonable (mean=1.5)
# [168/259] Fetching: ['malicious', 'traumatic', 'foregone', 'slowed']
#   KEPT malicious (mean=3.9)
#   KEPT traumatic (mean=6.0)
#   DROPPED foregone (not finance-relevant)
#   KEPT slowed (mean=3.5)
# [169/259] Fetching: ['plea', 'unfavorable', 'negatives', 'inaction']
#   KEPT plea (mean=5.1)
#   KEPT unfavorable (mean=0.7)
#   KEPT negatives (mean=3.8)
#   DROPPED inaction (not finance-relevant)
# [170/259] Fetching: ['falsify', 'aftermath', 'untrusted', 'recalls']
#   DROPPED falsify (not finance-relevant)
#   KEPT aftermath (mean=5.7)
#   DROPPED untrusted (not finance-relevant)
#   KEPT recalls (mean=9.2)
# [171/259] Fetching: ['coercion', 'exculpation', 'rejects', 'excited']
#   KEPT coercion (mean=1.5)
#   DROPPED exculpation (not finance-relevant)
#   KEPT rejects (mean=3.7)
#   KEPT excited (mean=10.6)
# [172/259] Fetching: ['cautious', 'happiest', 'outage', 'protesters']
#   KEPT cautious (mean=1.0)
#   KEPT happiest (mean=1.8)
#   KEPT outage (mean=44.2)
#   KEPT protesters (mean=0.9)
# [173/259] Fetching: ['satisfied', 'unfairly', 'bribe', 'rationalization']
#   KEPT satisfied (mean=3.6)
#   KEPT unfairly (mean=0.8)
#   KEPT bribe (mean=1.7)
#   KEPT rationalization (mean=0.5)
# [174/259] Fetching: ['revoked', 'devastated', 'overstatement', 'abolished']
#   KEPT revoked (mean=2.5)
#   KEPT devastated (mean=1.1)
#   DROPPED overstatement (not finance-relevant)
#   KEPT abolished (mean=2.9)
# [175/259] Fetching: ['suddenly', 'inactivate', 'counterclaim', 'erode']
#   KEPT suddenly (mean=23.8)
#   DROPPED inactivate (not finance-relevant)
#   KEPT counterclaim (mean=1.5)
#   KEPT erode (mean=0.9)
# [176/259] Fetching: ['dissent', 'stabilizing', 'stopping', 'scandals']
#   KEPT dissent (mean=2.1)
#   KEPT stabilizing (mean=1.4)
#   KEPT stopping (mean=19.1)
#   KEPT scandals (mean=1.8)
# [177/259] Fetching: ['overdue', 'fired', 'monopoly', 'uncontrollably']
#   KEPT overdue (mean=1.0)
#   KEPT fired (mean=39.4)
#   KEPT monopoly (mean=25.2)
#   KEPT uncontrollably (mean=1.0)
# [178/259] Fetching: ['miss', 'catastrophe', 'accomplishments', 'revolutionize']
#   KEPT miss (mean=40.6)
#   KEPT catastrophe (mean=0.3)
#   KEPT accomplishments (mean=2.2)
#   DROPPED revolutionize (not finance-relevant)
# [179/259] Fetching: ['threat', 'forestall', 'destroyed', 'arrest']
#   KEPT threat (mean=11.3)
#   DROPPED forestall (not finance-relevant)
#   KEPT destroyed (mean=6.7)
#   KEPT arrest (mean=40.2)
# [180/259] Fetching: ['discredit', 'nondisclosure', 'encouraged', 'warning']
#   DROPPED discredit (not finance-relevant)
#   DROPPED nondisclosure (not finance-relevant)
#   KEPT encouraged (mean=0.8)
#   KEPT warning (mean=40.8)
# [181/259] Fetching: ['miscalculated', 'predictions', 'inaccurate', 'tortuous']
#   DROPPED miscalculated (not finance-relevant)
#   KEPT predictions (mean=35.0)
#   KEPT inaccurate (mean=1.7)
#   KEPT tortuous (mean=0.9)
# [182/259] Fetching: ['winning', 'stops', 'deters', 'deficit']
#   KEPT winning (mean=49.4)
#   KEPT stops (mean=19.0)
#   DROPPED deters (not finance-relevant)
#   KEPT deficit (mean=6.5)
# [183/259] Fetching: ['disputes', 'forfeit', 'confines', 'assumption']
#   KEPT disputes (mean=2.5)
#   KEPT forfeit (mean=1.1)
#   DROPPED confines (not finance-relevant)
#   KEPT assumption (mean=7.6)
# [184/259] Fetching: ['delinquency', 'nonfunctional', 'overturn', 'protest']
#   KEPT delinquency (mean=1.7)
#   DROPPED nonfunctional (not finance-relevant)
#   KEPT overturn (mean=1.3)
#   KEPT protest (mean=19.1)
# [185/259] Fetching: ['foreclosures', 'complaining', 'ill', 'unfair']
#   KEPT foreclosures (mean=4.0)
#   KEPT complaining (mean=3.3)
#   KEPT ill (mean=34.4)
#   KEPT unfair (mean=4.3)
# [186/259] Fetching: ['understated', 'leading', 'delayed', 'onerous']
#   DROPPED understated (not finance-relevant)
#   KEPT leading (mean=30.2)
#   KEPT delayed (mean=17.7)
#   KEPT onerous (mean=0.7)
# [187/259] Fetching: ['condemned', 'defect', 'somewhere', 'escalate']
#   KEPT condemned (mean=2.0)
#   KEPT defect (mean=6.4)
#   KEPT somewhere (mean=16.2)
#   KEPT escalate (mean=1.0)
# [188/259] Fetching: ['adverse', 'usurp', 'redact', 'arrested']
#   KEPT adverse (mean=5.3)
#   DROPPED usurp (not finance-relevant)
#   KEPT redact (mean=1.0)
#   KEPT arrested (mean=37.5)
# [189/259] Fetching: ['resign', 'objections', 'secrecy', 'unsustainable']
#   KEPT resign (mean=4.7)
#   KEPT objections (mean=1.3)
#   KEPT secrecy (mean=1.0)
#   DROPPED unsustainable (not finance-relevant)
# [190/259] Fetching: ['violent', 'deprived', 'coercive', 'derelict']
#   KEPT violent (mean=17.8)
#   KEPT deprived (mean=2.0)
#   KEPT coercive (mean=1.3)
#   KEPT derelict (mean=1.3)
# [191/259] Fetching: ['abolish', 'downgrade', 'implicate', 'wasting']
#   KEPT abolish (mean=2.5)
#   KEPT downgrade (mean=3.5)
#   DROPPED implicate (not finance-relevant)
#   KEPT wasting (mean=3.4)
# [192/259] Fetching: ['unanticipated', 'violations', 'shutting', 'obstruction']
#   DROPPED unanticipated (not finance-relevant)
#   KEPT violations (mean=7.4)
#   KEPT shutting (mean=9.4)
#   KEPT obstruction (mean=7.6)
# [193/259] Fetching: ['abundance', 'overstate', 'precipitous', 'diminish']
#   KEPT abundance (mean=5.5)
#   DROPPED overstate (not finance-relevant)
#   KEPT precipitous (mean=0.4)
#   KEPT diminish (mean=1.3)
# [194/259] Fetching: ['incapable', 'confrontational', 'suspect', 'untruth']
#   KEPT incapable (mean=1.0)
#   DROPPED confrontational (not finance-relevant)
#   KEPT suspect (mean=12.9)
#   DROPPED untruth (not finance-relevant)
# [195/259] Fetching: ['hardship', 'rationalizing', 'mislabeled', 'uncollectible']
#   KEPT hardship (mean=6.5)
#   DROPPED rationalizing (not finance-relevant)
#   DROPPED mislabeled (not finance-relevant)
#   KEPT uncollectible (mean=0.4)
# [196/259] Fetching: ['impending', 'bribery', 'uncovered', 'danger']
#   KEPT impending (mean=1.8)
#   KEPT bribery (mean=1.2)
#   KEPT uncovered (mean=2.2)
#   KEPT danger (mean=28.8)
# [197/259] Fetching: ['misinformed', 'mismatched', 'complimentary', 'revoke']
#   DROPPED misinformed (not finance-relevant)
#   KEPT mismatched (mean=1.0)
#   KEPT complimentary (mean=3.5)
#   KEPT revoke (mean=2.0)
# [198/259] Fetching: ['abolishing', 'disavow', 'refuses', 'reparation']
#   KEPT abolishing (mean=0.3)
#   DROPPED disavow (not finance-relevant)
#   KEPT refuses (mean=5.9)
#   KEPT reparation (mean=1.1)
# [199/259] Fetching: ['insecure', 'disregarded', 'threats', 'aggravation']
#   KEPT insecure (mean=6.9)
#   KEPT disregarded (mean=0.9)
#   KEPT threats (mean=7.5)
#   DROPPED aggravation (not finance-relevant)
# [200/259] Fetching: ['demotion', 'misplaced', 'untimely', 'fluctuates']
#   DROPPED demotion (not finance-relevant)
#   KEPT misplaced (mean=1.0)
#   DROPPED untimely (not finance-relevant)
#   KEPT fluctuates (mean=0.7)
# [201/259] Fetching: ['voiding', 'refused', 'condemn', 'diversion']
#   KEPT voiding (mean=0.8)
#   KEPT refused (mean=5.7)
#   KEPT condemn (mean=1.7)
#   KEPT diversion (mean=3.3)
# [202/259] Fetching: ['assuming', 'toleration', 'boom', 'defective']
#   KEPT assuming (mean=6.3)
#   KEPT toleration (mean=0.4)
#   KEPT boom (mean=43.1)
#   KEPT defective (mean=3.1)
# [203/259] Fetching: ['tragic', 'eroded', 'severe', 'presume']
#   KEPT tragic (mean=1.7)
#   DROPPED eroded (not finance-relevant)
#   KEPT severe (mean=33.1)
#   DROPPED presume (not finance-relevant)
# [204/259] Fetching: ['dependable', 'alerted', 'randomness', 'unknowingly']
#   KEPT dependable (mean=2.4)
#   DROPPED alerted (not finance-relevant)
#   DROPPED randomness (not finance-relevant)
#   DROPPED unknowingly (not finance-relevant)
# [205/259] Fetching: ['dissident', 'informative', 'approximate', 'abnormality']
#   KEPT dissident (mean=0.6)
#   KEPT informative (mean=3.4)
#   KEPT approximate (mean=6.0)
#   KEPT abnormality (mean=2.1)
# [206/259] Fetching: ['accomplish', 'setback', 'volatility', 'depressing']
#   KEPT accomplish (mean=6.2)
#   KEPT setback (mean=1.6)
#   KEPT volatility (mean=2.3)
#   KEPT depressing (mean=1.8)
# [207/259] Fetching: ['forfeiture', 'accused', 'anticipation', 'hindrance']
#   KEPT forfeiture (mean=1.0)
#   KEPT accused (mean=12.9)
#   KEPT anticipation (mean=1.9)
#   KEPT hindrance (mean=0.7)
# [208/259] Fetching: ['devastating', 'perpetrate', 'incompetence', 'underpayment']
#   KEPT devastating (mean=1.4)
#   DROPPED perpetrate (not finance-relevant)
#   KEPT incompetence (mean=1.0)
#   KEPT underpayment (mean=0.5)
# [209/259] Fetching: ['layoffs', 'variant', 'offenders', 'disproportion']
#   KEPT layoffs (mean=24.0)
#   KEPT variant (mean=12.2)
#   KEPT offenders (mean=8.5)
#   DROPPED disproportion (not finance-relevant)
# [210/259] Fetching: ['fugitive', 'acquitted', 'likelihood', 'boycott']
#   KEPT fugitive (mean=5.9)
#   KEPT acquitted (mean=1.2)
#   KEPT likelihood (mean=5.5)
#   KEPT boycott (mean=10.3)
# [211/259] Fetching: ['misjudged', 'strongest', 'downtime', 'enhances']
#   DROPPED misjudged (not finance-relevant)
#   KEPT strongest (mean=36.9)
#   KEPT downtime (mean=2.5)
#   KEPT enhances (mean=1.1)
# [212/259] Fetching: ['precipitated', 'disparagement', 'happily', 'disorderly']
#   KEPT precipitated (mean=0.3)
#   DROPPED disparagement (not finance-relevant)
#   KEPT happily (mean=2.8)
#   KEPT disorderly (mean=1.2)
# [213/259] Fetching: ['conflict', 'disagreements', 'retribution', 'alienate']
#   KEPT conflict (mean=31.3)
#   KEPT disagreements (mean=0.5)
#   KEPT retribution (mean=3.3)
#   DROPPED alienate (not finance-relevant)
# [214/259] Fetching: ['disapproved', 'disturbing', 'abrogate', 'possibly']
#   DROPPED disapproved (not finance-relevant)
#   KEPT disturbing (mean=3.0)
#   DROPPED abrogate (not finance-relevant)
#   KEPT possibly (mean=3.5)
# [215/259] Fetching: ['verdict', 'unconfirmed', 'disqualifies', 'improves']
#   KEPT verdict (mean=8.3)
#   DROPPED unconfirmed (not finance-relevant)
#   KEPT disqualifies (mean=0.8)
#   KEPT improves (mean=2.5)
# [216/259] Fetching: ['contradictions', 'disloyalty', 'defeated', 'unauthorized']
#   KEPT contradictions (mean=0.7)
#   DROPPED disloyalty (not finance-relevant)
#   KEPT defeated (mean=4.9)
#   KEPT unauthorized (mean=3.6)
# [217/259] Fetching: ['anticipate', 'presumed', 'injured', 'tainted']
#   KEPT anticipate (mean=1.9)
#   KEPT presumed (mean=1.0)
#   KEPT injured (mean=19.2)
#   KEPT tainted (mean=3.0)
# [218/259] Fetching: ['lagging', 'hindered', 'demolished', 'peril']
#   KEPT lagging (mean=5.3)
#   KEPT hindered (mean=0.6)
#   KEPT demolished (mean=1.1)
#   KEPT peril (mean=2.0)
# [219/259] Fetching: ['advancements', 'disturbance', 'degraded', 'unprofitable']
#   KEPT advancements (mean=1.9)
#   KEPT disturbance (mean=2.9)
#   KEPT degraded (mean=1.0)
#   DROPPED unprofitable (not finance-relevant)
# [220/259] Fetching: ['kickbacks', 'quit', 'anticipated', 'misstatements']
#   KEPT kickbacks (mean=1.0)
#   KEPT quit (mean=36.4)
#   KEPT anticipated (mean=1.9)
#   DROPPED misstatements (not finance-relevant)
# [221/259] Fetching: ['defraud', 'invalidated', 'complication', 'revoking']
#   DROPPED defraud (not finance-relevant)
#   DROPPED invalidated (not finance-relevant)
#   KEPT complication (mean=2.8)
#   DROPPED revoking (not finance-relevant)
# [222/259] Fetching: ['culpability', 'obscene', 'slowest', 'exaggerate']
#   DROPPED culpability (not finance-relevant)
#   KEPT obscene (mean=1.0)
#   KEPT slowest (mean=2.1)
#   KEPT exaggerate (mean=0.8)
# [223/259] Fetching: ['ambiguous', 'abnormalities', 'interrupt', 'omissions']
#   KEPT ambiguous (mean=3.7)
#   KEPT abnormalities (mean=2.0)
#   KEPT interrupt (mean=2.0)
#   KEPT omissions (mean=0.5)
# [224/259] Fetching: ['plead', 'invalidation', 'reassigned', 'concealing']
#   KEPT plead (mean=3.0)
#   DROPPED invalidation (not finance-relevant)
#   DROPPED reassigned (not finance-relevant)
#   DROPPED concealing (not finance-relevant)
# [225/259] Fetching: ['injury', 'immoral', 'undetermined', 'persistence']
#   KEPT injury (mean=26.2)
#   DROPPED immoral (not finance-relevant)
#   DROPPED undetermined (not finance-relevant)
#   DROPPED persistence (not finance-relevant)
# [226/259] Fetching: ['grievances', 'declined', 'unrealistic', 'destroying']
#   KEPT grievances (mean=1.4)
#   KEPT declined (mean=5.4)
#   KEPT unrealistic (mean=1.0)
#   KEPT destroying (mean=3.7)
# [227/259] Fetching: ['negligent', 'crucial', 'may', 'unannounced']
#   DROPPED negligent (not finance-relevant)
#   KEPT crucial (mean=0.7)
#   KEPT may (mean=26.2)
#   DROPPED unannounced (not finance-relevant)
# [228/259] Fetching: ['encourages', 'lapse', 'confusion', 'ignore']
#   KEPT encourages (mean=2.1)
#   KEPT lapse (mean=4.9)
#   KEPT confusion (mean=6.8)
#   KEPT ignore (mean=10.8)
# [229/259] Fetching: ['conspirators', 'disappearing', 'dishonor', 'unrest']
#   KEPT conspirators (mean=0.3)
#   KEPT disappearing (mean=4.1)
#   KEPT dishonor (mean=1.0)
#   KEPT unrest (mean=1.5)
# [230/259] Fetching: ['distort', 'annul', 'prolong', 'delays']
#   KEPT distort (mean=1.0)
#   KEPT annul (mean=0.4)
#   KEPT prolong (mean=1.3)
#   KEPT delays (mean=11.7)
# [231/259] Fetching: ['overpaid', 'losing', 'relinquishing', 'divesting']
#   KEPT overpaid (mean=0.7)
#   KEPT losing (mean=54.9)
#   DROPPED relinquishing (not finance-relevant)
#   DROPPED divesting (not finance-relevant)
# [232/259] Fetching: ['appears', 'limitation', 'seize', 'unintentionally']
#   KEPT appears (mean=10.2)
#   KEPT limitation (mean=4.3)
#   KEPT seize (mean=3.7)
#   KEPT unintentionally (mean=0.6)
# [233/259] Fetching: ['restructure', 'condemnation', 'confined', 'devastation']
#   DROPPED restructure (not finance-relevant)
#   KEPT condemnation (mean=1.1)
#   KEPT confined (mean=2.5)
#   KEPT devastation (mean=1.0)
# [234/259] Fetching: ['acquiesce', 'unaware', 'harsh', 'curtailed']
#   KEPT acquiesce (mean=1.0)
#   KEPT unaware (mean=1.7)
#   KEPT harsh (mean=4.9)
#   DROPPED curtailed (not finance-relevant)
# [235/259] Fetching: ['adversity', 'investigate', 'disapproving', 'variables']
#   KEPT adversity (mean=3.2)
#   KEPT investigate (mean=6.5)
#   DROPPED disapproving (not finance-relevant)
#   KEPT variables (mean=23.0)
# [236/259] Fetching: ['conducive', 'embarrassment', 'cancellation', 'distractions']
#   KEPT conducive (mean=1.1)
#   KEPT embarrassment (mean=1.0)
#   KEPT cancellation (mean=16.3)
#   KEPT distractions (mean=1.0)
# [237/259] Fetching: ['disrupted', 'excessive', 'stronger', 'inconclusive']
#   KEPT disrupted (mean=1.0)
#   KEPT excessive (mean=24.3)
#   KEPT stronger (mean=27.8)
#   KEPT inconclusive (mean=0.9)
# [238/259] Fetching: ['complains', 'revocation', 'uncertain', 'protests']
#   KEPT complains (mean=2.0)
#   KEPT revocation (mean=1.3)
#   KEPT uncertain (mean=1.6)
#   KEPT protests (mean=9.4)
# [239/259] Fetching: ['relinquishment', 'winner', 'persists', 'testify']
#   DROPPED relinquishment (not finance-relevant)
#   KEPT winner (mean=49.7)
#   KEPT persists (mean=0.4)
#   KEPT testify (mean=2.2)
# [240/259] Fetching: ['shuts', 'risked', 'undetected', 'dishonesty']
#   KEPT shuts (mean=6.2)
#   DROPPED risked (not finance-relevant)
#   KEPT undetected (mean=0.9)
#   KEPT dishonesty (mean=0.7)
# [241/259] Fetching: ['presumption', 'destructive', 'disqualified', 'overruns']
#   KEPT presumption (mean=0.9)
#   KEPT destructive (mean=3.3)
#   KEPT disqualified (mean=1.4)
#   DROPPED overruns (not finance-relevant)
# [242/259] Fetching: ['noncompliant', 'repudiated', 'recalculate', 'deviate']
#   DROPPED noncompliant (not finance-relevant)
#   DROPPED repudiated (not finance-relevant)
#   DROPPED recalculate (not finance-relevant)
#   KEPT deviate (mean=1.0)
# [243/259] Fetching: ['seized', 'disagrees', 'underperformance', 'rejecting']
#   KEPT seized (mean=3.3)
#   KEPT disagrees (mean=0.5)
#   DROPPED underperformance (not finance-relevant)
#   KEPT rejecting (mean=2.0)
# [244/259] Fetching: ['variation', 'breaks', 'unapproved', 'refusing']
#   KEPT variation (mean=9.2)
#   KEPT breaks (mean=35.6)
#   DROPPED unapproved (not finance-relevant)
#   KEPT refusing (mean=4.0)
# [245/259] Fetching: ['alienated', 'tightening', 'unstable', 'undermining']
#   KEPT alienated (mean=0.6)
#   KEPT tightening (mean=5.4)
#   KEPT unstable (mean=6.9)
#   DROPPED undermining (not finance-relevant)
# [246/259] Fetching: ['deter', 'malfunction', 'succeeded', 'detriment']
#   KEPT deter (mean=4.7)
#   KEPT malfunction (mean=6.2)
#   KEPT succeeded (mean=1.1)
#   KEPT detriment (mean=0.7)
# [247/259] Fetching: ['denying', 'mismanaged', 'susceptibility', 'misappropriate']
#   KEPT denying (mean=1.8)
#   DROPPED mismanaged (not finance-relevant)
#   KEPT susceptibility (mean=1.0)
#   DROPPED misappropriate (not finance-relevant)
# [248/259] Fetching: ['inconvenience', 'interfere', 'distract', 'contested']
#   KEPT inconvenience (mean=2.1)
#   KEPT interfere (mean=4.8)
#   KEPT distract (mean=1.5)
#   KEPT contested (mean=1.0)
# [249/259] Fetching: ['unreconciled', 'winners', 'exploiting', 'confront']
#   DROPPED unreconciled (not finance-relevant)
#   KEPT winners (mean=22.9)
#   DROPPED exploiting (not finance-relevant)
#   KEPT confront (mean=1.0)
# [250/259] Fetching: ['prosecuting', 'destroys', 'contradicting', 'missteps']
#   KEPT prosecuting (mean=1.0)
#   KEPT destroys (mean=3.0)
#   DROPPED contradicting (not finance-relevant)
#   DROPPED missteps (not finance-relevant)
# [251/259] Fetching: ['inefficiency', 'obsolescence', 'annoyed', 'defrauded']
#   DROPPED inefficiency (not finance-relevant)
#   KEPT obsolescence (mean=1.0)
#   KEPT annoyed (mean=2.7)
#   DROPPED defrauded (not finance-relevant)
# [252/259] Fetching: ['enjoying', 'disapproves', 'vulnerabilities', 'reassessed']
#   KEPT enjoying (mean=2.1)
#   DROPPED disapproves (not finance-relevant)
#   KEPT vulnerabilities (mean=1.5)
#   DROPPED reassessed (not finance-relevant)
# [253/259] Fetching: ['overages', 'diligently', 'insufficiency', 'stabilization']
#   DROPPED overages (not finance-relevant)
#   KEPT diligently (mean=1.0)
#   KEPT insufficiency (mean=4.3)
#   KEPT stabilization (mean=2.6)
# [254/259] Fetching: ['defamed', 'disappointing', 'convicted', 'inactivation']
#   DROPPED defamed (not finance-relevant)
#   KEPT disappointing (mean=1.0)
#   KEPT convicted (mean=8.8)
#   DROPPED inactivation (not finance-relevant)
# [255/259] Fetching: ['uncompetitive', 'diminishing', 'complicated', 'subjected']
#   DROPPED uncompetitive (not finance-relevant)
#   KEPT diminishing (mean=1.5)
#   KEPT complicated (mean=6.0)
#   KEPT subjected (mean=1.4)
# [256/259] Fetching: ['unsold', 'demolish', 'riskiest', 'enjoys']
#   KEPT unsold (mean=0.9)
#   KEPT demolish (mean=1.0)
#   DROPPED riskiest (not finance-relevant)
#   KEPT enjoys (mean=2.2)
# [257/259] Fetching: ['impossible', 'inequity', 'unproven', 'charitable']
#   KEPT impossible (mean=20.0)
#   DROPPED inequity (not finance-relevant)
#   DROPPED unproven (not finance-relevant)
#   KEPT charitable (mean=2.9)
# [258/259] Fetching: ['standstill', 'predicts', 'sentencing', 'interference']
#   DROPPED standstill (not finance-relevant)
#   KEPT predicts (mean=2.2)
#   KEPT sentencing (mean=6.4)
#   KEPT interference (mean=6.1)
# [259/259] Fetching: ['reward', 'disagree', 'slowing']
#   KEPT reward (mean=21.7)
#   KEPT disagree (mean=3.3)
#   KEPT slowing (mean=3.1)
#
# Before finance filter: 1035
# After finance filter:  884
#       keyword  zero_pct  mean_interest
# 0      broken       0.0          92.74
# 1         bad       0.0          92.23
# 2     rewards       0.0          89.58
# 3       error       0.0          89.57
# 4       great       0.0          89.09
# 5         cut       0.0          88.15
# 6    problems       0.0          86.62
# 7        loss       0.0          86.11
# 8   questions       0.0          85.75
# 9      strong       0.0          84.91
# 10     hidden       0.0          84.51
# 11       good       0.0          83.51
# 12      crime       0.0          83.45
# 13       best       0.0          83.38
# 14       late       0.0          83.30
# 15       hurt       0.0          83.19
# 16    problem       0.0          82.64
# 17      force       0.0          82.57
# 18    popular       0.0          82.23
# 19    against       0.0          81.83

# %%
# Filter again for mean <= 20
finance_survivors_filtered = finance_survivors_df[finance_survivors_df['mean_interest'] >= 20].reset_index(drop=True)

print(f"After zero filter:     {len(finance_survivors_df)}")
print(f"After interest filter: {len(finance_survivors_filtered)}")
print(f"Dropped by filter 4:   {len(finance_survivors_df) - len(finance_survivors_filtered)}")
finance_survivors_filtered
# Out:
# After zero filter:     884
# After interest filter: 174
# Dropped by filter 4:   710
#           keyword  zero_pct  mean_interest
# 0          broken       0.0          92.74
# 1             bad       0.0          92.23
# 2         rewards       0.0          89.58
# 3           error       0.0          89.57
# 4           great       0.0          89.09
# ..            ...       ...            ...
# 169  discontinued       0.0          20.83
# 170        breach       0.0          20.75
# 171  intermittent       0.0          20.60
# 172     deviation       0.0          20.53
# 173      shortage       0.0          20.02
#
# [174 rows x 3 columns]

# %%
finance_survivors_filtered.to_csv('lm_dict_survivors.csv', index=False)
print(f"Saved {len(finance_survivors_filtered)} words to lm_dict_survivors.csv")
# Out:
# Saved 174 words to lm_dict_survivors.csv

# %% [markdown]
# ## Category 2, 3, 4: LLM-assisted Generation

# %%
# Analysis on LLM-assisted Generation--more to come

file_path = "Project/Google Search Trends Data.xlsx"
llm_cat2 = pd.read_excel(file_path, sheet_name='Category 2')
llm_cat2 = llm_cat2.iloc[1:].reset_index(drop=True)
llm_cat2.columns = ['ChatGPT', 'Claude', 'Gemini']

llm_cat2
# Out:
#                 ChatGPT             Claude               Gemini
# 0    stock market crash        stock crash         Market crash
# 1          market crash       market crash          Bear market
# 2             recession     stock sell-off     Stock volatility
# 3           bear market        bear market          Margin call
# 4      financial crisis        margin call        Panic selling
# ..                  ...                ...                  ...
# 145     inflation spike        yield curve       Capital flight
# 146      hyperinflation      credit crunch    Asset devaluation
# 147         stagflation      short selling          Stagflation
# 148       housing crash  stock liquidation  Quantitative easing
# 149       systemic risk     capital flight  Financial contagion
#
# [150 rows x 3 columns]

# %%
# Combine all keywords

file_path = "Project/Google Search Trends Data.xlsx"
xl = pd.ExcelFile(file_path)

all_words = []

for sheet in xl.sheet_names:
    df = pd.read_excel(file_path, sheet_name=sheet, header=None)
    
    # Skip first row (LLM names), rename columns
    df = df.iloc[2:].reset_index(drop=True)
    df.columns = ['ChatGPT', 'Claude', 'Gemini']
    
    # Melt into one column and tag with sheet name
    melted = pd.melt(df, var_name='source', value_name='keyword')
    melted['category'] = sheet
    all_words.append(melted)

# Combine all sheets
combined = pd.concat(all_words, ignore_index=True)
combined
# Out:
#        source                 keyword                category
# 0     ChatGPT      stock market crash              Category 2
# 1     ChatGPT            market crash              Category 2
# 2     ChatGPT               recession              Category 2
# 3     ChatGPT             bear market              Category 2
# 4     ChatGPT        financial crisis              Category 2
# ...       ...                     ...                     ...
# 5995   Gemini           Build to rent  Category 4 Real Estate
# 5996   Gemini      Suburban migration  Category 4 Real Estate
# 5997   Gemini      Affordable housing  Category 4 Real Estate
# 5998   Gemini     Distressed property  Category 4 Real Estate
# 5999   Gemini  Real estate investment  Category 4 Real Estate
#
# [6000 rows x 3 columns]

# %%
combined['keyword'] = combined['keyword'].dropna().str.strip().str.lower()
combined = combined.dropna(subset=['keyword'])

print(f"Total raw entries: {len(combined)}")
# Out:
# Total raw entries: 6000

# %%
combined_deduped = combined.drop_duplicates(subset='keyword').reset_index(drop=True)

print(f"After deduplication: {len(combined_deduped)}")
combined_deduped
# Out:
# After deduplication: 1811
#        source              keyword                category
# 0     ChatGPT   stock market crash              Category 2
# 1     ChatGPT         market crash              Category 2
# 2     ChatGPT            recession              Category 2
# 3     ChatGPT          bear market              Category 2
# 4     ChatGPT     financial crisis              Category 2
# ...       ...                  ...                     ...
# 1806   Gemini      green buildings  Category 4 Real Estate
# 1807   Gemini        urban renewal  Category 4 Real Estate
# 1808   Gemini   suburban migration  Category 4 Real Estate
# 1809   Gemini   affordable housing  Category 4 Real Estate
# 1810   Gemini  distressed property  Category 4 Real Estate
#
# [1811 rows x 3 columns]

# %% [markdown]
# ### Category 2: Adding FEARS index

# %%
fears_words = [
    "gold prices", "recession", "gold price", "depression", "great depression",
    "gold", "economy", "price of gold", "the depression", "crisis",
    "frugal", "gdp", "charity", "bankruptcy", "unemployment",
    "inflation rate", "bankrupt", "the great depression", "car donate",
    "capitalization", "expense", "donation", "savings", "social security card",
    "the crisis", "default", "benefits", "unemployed", "poverty",
    "social security office"
]

fears_df = pd.DataFrame({
    'keyword': fears_words,
    'source': 'FEARS',
    'category': 'Category 2'
})

# Check which are already in combined_deduped
already_in = fears_df['keyword'].isin(combined_deduped['keyword'])
print(f"Already in dataset: {already_in.sum()}")
print(f"Missing, will add: {(~already_in).sum()}")
print("\nMissing words:")
print(fears_df[~already_in]['keyword'].tolist())

# Add missing ones
missing_fears = fears_df[~already_in]
combined_deduped = pd.concat([combined_deduped, missing_fears], ignore_index=True)
print(f"\nNew total: {len(combined_deduped)}")
# Out:
# Already in dataset: 8
# Missing, will add: 22
#
# Missing words:
# ['depression', 'great depression', 'economy', 'price of gold', 'the depression', 'crisis', 'frugal', 'charity', 'bankrupt', 'the great depression', 'car donate', 'capitalization', 'expense', 'donation', 'savings', 'social security card', 'the crisis', 'default', 'benefits', 'unemployed', 'poverty', 'social security office']
#
# New total: 1833

# %%
import re

# Normalize whitespace — collapse multiple spaces, strip edges
combined_deduped['keyword'] = combined_deduped['keyword'].str.replace(r'\s+', ' ', regex=True).str.strip()

# Deduplicate again after normalization
combined_deduped = combined_deduped.drop_duplicates(subset='keyword').reset_index(drop=True)

print(f"After whitespace normalization: {len(combined_deduped)}")

# Remove all spaces and check for duplicates
combined_deduped['keyword_nospace'] = combined_deduped['keyword'].str.replace(' ', '')
dupes = combined_deduped[combined_deduped.duplicated(subset='keyword_nospace', keep=False)]
print(dupes.sort_values('keyword_nospace')[['keyword', 'keyword_nospace']])
# Out:
# After whitespace normalization: 1833
#                 keyword   keyword_nospace
# 12        bank collapse      bankcollapse
# 61         bankcollapse      bankcollapse
# 11         bank failure       bankfailure
# 60          bankfailure       bankfailure
# 78       banking crisis     bankingcrisis
# 59        bankingcrisis     bankingcrisis
# 3           bear market        bearmarket
# 51           bearmarket        bearmarket
# 71          bonddefault       bonddefault
# 83         bond default       bonddefault
# 105      capital flight     capitalflight
# 74        capitalflight     capitalflight
# 8         credit crisis      creditcrisis
# 56         creditcrisis      creditcrisis
# 1271      cybersecurity     cybersecurity
# 1392     cyber security     cybersecurity
# 58           debtcrisis        debtcrisis
# 9           debt crisis        debtcrisis
# 70          defaultrisk       defaultrisk
# 128        default risk       defaultrisk
# 291          exxonmobil        exxonmobil
# 305         exxon mobil        exxonmobil
# 53      financialcrisis   financialcrisis
# 4      financial crisis   financialcrisis
# 1752      home builders      homebuilders
# 731        homebuilders      homebuilders
# 143      inverted yield     invertedyield
# 68        invertedyield     invertedyield
# 69            junkbonds         junkbonds
# 44           junk bonds         junkbonds
# 13     liquidity crisis   liquiditycrisis
# 57      liquiditycrisis   liquiditycrisis
# 14          margin call        margincall
# 72           margincall        margincall
# 1          market crash       marketcrash
# 50          marketcrash       marketcrash
# 102     market downturn    marketdownturn
# 54       marketdownturn    marketdownturn
# 63     marketvolatility  marketvolatility
# 15    market volatility  marketvolatility
# 1103            medtech           medtech
# 1075           med tech           medtech
# 75     sovereigndefault  sovereigndefault
# 10    sovereign default  sovereigndefault
# 19     stock correction   stockcorrection
# 66      stockcorrection   stockcorrection
# 49           stockcrash        stockcrash
# 30          stock crash        stockcrash
# 85          stock panic        stockpanic
# 73           stockpanic        stockpanic
# 64          stockplunge       stockplunge
# 98         stock plunge       stockplunge
# 52         stockselloff      stockselloff
# 6         stock selloff      stockselloff
# 16     stock volatility   stockvolatility
# 62      stockvolatility   stockvolatility
# 67       yieldinversion    yieldinversion
# 81      yield inversion    yieldinversion

# %%
# For duplicates, keep the one with spaces (drop the no-space version)
combined_deduped['has_no_space'] = combined_deduped['keyword'] == combined_deduped['keyword_nospace']

# Sort so spaced version comes first, then drop duplicates keeping first
combined_deduped = combined_deduped.sort_values('has_no_space').drop_duplicates(subset='keyword_nospace', keep='first')

# Clean up helper columns
combined_deduped = combined_deduped.drop(columns=['keyword_nospace', 'has_no_space']).reset_index(drop=True)

print(f"After removing no-space duplicates: {len(combined_deduped)}")
# Out:
# After removing no-space duplicates: 1804

# %%
combined_deduped
# Out:
#        source             keyword                category
# 0     ChatGPT  stock market crash              Category 2
# 1     ChatGPT   property casualty   Category 4 Financials
# 2     ChatGPT      life insurance   Category 4 Financials
# 3     ChatGPT  commercial banking   Category 4 Financials
# 4     ChatGPT  money center banks   Category 4 Financials
# ...       ...                 ...                     ...
# 1799   Gemini         warehousing  Category 4 Industrials
# 1800  ChatGPT            stimulus              Category 3
# 1801  ChatGPT           railroads  Category 4 Industrials
# 1802   Gemini         outsourcing  Category 4 Industrials
# 1803  ChatGPT              cement    Category 4 Materials
#
# [1804 rows x 3 columns]

# %%
# Filter 1

TIMEFRAME   = "2023-01-01 2023-12-31"
GEO         = "US"
ZERO_THRESH = 0.90
DELAY       = 15
BATCH_SIZE  = 5
CHECKPOINT  = "llm_survivors_checkpoint.csv"

# Prep keyword list
keywords = combined_deduped['keyword'].str.lower().str.strip().unique().tolist()
print(f"Total keywords to test: {len(keywords)}")

batches = [keywords[i:i+BATCH_SIZE] for i in range(0, len(keywords), BATCH_SIZE)]
print(f"Total batches: {len(batches)}")

# Resume from checkpoint if it exists
if os.path.exists(CHECKPOINT):
    checkpoint_df = pd.read_csv(CHECKPOINT)
    survivors = {row['keyword']: {"zero_pct": row['zero_pct'], "mean_interest": row['mean_interest']} 
                 for _, row in checkpoint_df.iterrows()}
    already_done = set(survivors.keys())
    print(f"Resuming from checkpoint — {len(already_done)} keywords already done")
else:
    survivors = {}
    already_done = set()
    print("Starting fresh")

dropped = []
pytrends = TrendReq(hl="en-US", tz=0, timeout=(10, 30))

for idx, batch in enumerate(batches, 1):
    if all(kw in already_done for kw in batch):
        print(f"[{idx}/{len(batches)}] Skipping (already done)")
        continue

    print(f"[{idx}/{len(batches)}] Fetching: {batch}")
    
    success = False
    for attempt in range(1, 4):
        try:
            pytrends.build_payload(batch, timeframe=TIMEFRAME, geo=GEO)
            raw = pytrends.interest_over_time()
            success = True
            break
        except Exception as exc:
            wait = DELAY * (2 ** (attempt - 1)) + random.uniform(0, 3)
            print(f"  Attempt {attempt}/3 failed — {exc}. Retrying in {wait:.1f}s")
            time.sleep(wait)
    
    if not success or raw.empty:
        print(f"  No data — dropping batch")
        dropped.extend(batch)
        continue

    raw = raw.drop(columns=["isPartial"], errors="ignore")

    for kw in batch:
        if kw not in raw.columns:
            dropped.append(kw)
            continue
        series = raw[kw]
        zero_pct = (series == 0).sum() / len(series)
        if zero_pct >= ZERO_THRESH:
            dropped.append(kw)
        else:
            survivors[kw] = {"zero_pct": round(zero_pct, 3), "mean_interest": round(series.mean(), 2)}

    if idx % 25 == 0:
        pd.DataFrame([{"keyword": kw, **v} for kw, v in survivors.items()]).to_csv(CHECKPOINT, index=False)
        print(f"  ✓ checkpoint saved at batch {idx}")

    if idx < len(batches):
        sleep_time = DELAY + random.uniform(0, DELAY * 0.4)
        time.sleep(sleep_time)

# Final save
survivors_df = pd.DataFrame([{"keyword": kw, **v} for kw, v in survivors.items()])
survivors_df = survivors_df.sort_values("mean_interest", ascending=False).reset_index(drop=True)
survivors_df.to_csv(CHECKPOINT, index=False)
survivors_df.to_csv("llm_survivors.csv", index=False)

print(f"\nStarted with : {len(keywords)}")
print(f"Survived     : {len(survivors_df)}")
print(f"Dropped      : {len(dropped)}")
survivors_df.head(20)
# Out:
# Total keywords to test: 1804
# Total batches: 361
# Resuming from checkpoint — 896 keywords already done
# [1/361] Fetching: ['stock market crash', 'property casualty', 'life insurance', 'commercial banking', 'money center banks']
# [2/361] Skipping (already done)
# [3/361] Skipping (already done)
# [4/361] Skipping (already done)
# [5/361] Fetching: ['payment processors', 'digital banking', 'fintech stocks', 'ipo market', 'online banking']
# [6/361] Fetching: ['mortgage reits', 'exchange stocks', 'fed rate', 'bank merger', 'crypto bank']
# [7/361] Skipping (already done)
# [8/361] Fetching: ['wall street', 'bank crisis', 'credit card', 'financial stocks', 'goldman sachs']
# [9/361] Skipping (already done)
# [10/361] Skipping (already done)
# [11/361] Fetching: ['private equity', 'wells fargo', 'wealth management', 'consumer lending', 'health services']
# [12/361] Skipping (already done)
# [13/361] Fetching: ['health it', 'drug patents', 'medical cannabis', 'health sector', 'medical equipment']
# [14/361] Fetching: ['ozempic stock', 'mrna stocks', 'pharmacy stocks', 'surgical robots', 'diagnostics stocks']
# [15/361] Fetching: ['medical ai', 'ozempic stocks', 'glp-1 stocks', 'oncology stocks', 'medicaid stocks']
# [16/361] Fetching: ['mental health stocks', 'medical imaging', 'weight loss', 'genomic medicine', 'health ai']
# [17/361] Fetching: ['credit cards', 'stress test', 'capital ratios', 'deposit outflows', 'net interest income']
# [18/361] Fetching: ['interest margins', 'bank earnings', 'loan defaults', 'regional banks', 'investment banks']
# [19/361] Fetching: ['commercial banks', 'financial sector', 'bank stocks', 'obesity medicine', 'health care']
# [20/361] Skipping (already done)
# [21/361] Fetching: ['pharmacy benefit', 'longevity tech', 'surgical robotics', 'asset management', 'mastercard stock']
# [22/361] Fetching: ['lending stocks', 'brokerage stocks', 'autonomous vehicles', 'blockchain technology', 'saas stocks']
# [23/361] Skipping (already done)
# [24/361] Skipping (already done)
# [25/361] Fetching: ['microsoft stock', 'apple stock', 'nvidia stock', 'magnificent seven', 'tech rally']
#   ✓ checkpoint saved at batch 25
# [26/361] Fetching: ['tech bubble', 'tech crash', 'tech earnings', 'software stocks', 'meta stock']
# [27/361] Skipping (already done)
# [28/361] Fetching: ['5g stocks', 'ai boom', 'chip shortage', 'broadcom stock', 'xlk etf']
# [29/361] Fetching: ['it sector etf', 'big tech', 'gpu demand', 'growth stocks', 'tech selloff']
# [30/361] Skipping (already done)
# [31/361] Fetching: ['automation software', 'edge computing', 'hardware stocks', 'alphabet stock', 'gpu stocks']
# [32/361] Skipping (already done)
# [33/361] Skipping (already done)
# [34/361] Skipping (already done)
# [35/361] Fetching: ['warren buffett', 'crypto banking', 'fintech bubble', 'fed rate hike', 'banking sector']
# [36/361] Fetching: ['credit card stocks', 'cryptocurrency banks', 'stock brokerage', 'blackrock stock', 'fdic insurance']
# [37/361] Fetching: ['loan rates', 'bank of america', 'bank dividends', 'open banking', 'medical insurance']
# [38/361] Fetching: ['loan growth', 'stablecoin regulation', 'financial planning', 'investment portfolio', 'lending standards']
# [39/361] Skipping (already done)
# [40/361] Fetching: ['loan applications', 'credit score', 'stablecoin law', 'savings yield', 'payment processing']
# [41/361] Skipping (already done)
# [42/361] Fetching: ['dividend yields', 'fraud detection', 'agentic ai banking', 'banking as a service', 'online lending']
# [43/361] Skipping (already done)
# [44/361] Fetching: ['organic food stocks', 'branded goods', 'cleaning products stocks', 'household brands', 'essential goods']
# [45/361] Fetching: ['cleaning products', 'food inflation', 'nestlé stock', 'philip morris', 'general mills']
# [46/361] Fetching: ['altria stock', 'coca-cola stock', 'procter gamble', 'premium brands', 'inventory glut']
# [47/361] Fetching: ['soda stocks', 'snack stocks', 'costco grocery', 'dividend staples', 'home care']
# [48/361] Fetching: ['personal care', 'grocery inflation', 'kellogg stock', 'dollar stores', 'staples dividend']
# [49/361] Fetching: ['consumer non-cyclicals', 'energy drinks', 'nicotine pouches', 'smoke-free products', 'healthy eating']
# [50/361] Fetching: ['glp-1 impact', 'cost of living', 'generic brands', 'value stocks', 'grocery stores']
#   ✓ checkpoint saved at batch 50
# [51/361] Skipping (already done)
# [52/361] Fetching: ['kroger stock', 'staples sector', 'food security', 'plant-based stocks', 'non-cyclical stocks']
# [53/361] Fetching: ['household essentials', 'household goods', 'inflation-proof stocks', 'snack foods', 'soft drinks']
# [54/361] Fetching: ['food producers', 'xlp etf', 'emerging markets demand', 'healthy snacks', 'plant based']
# [55/361] Fetching: ['organic foods', 'cash flow stability', 'recession proof', 'dividend aristocrats', 'dividend stocks']
# [56/361] Skipping (already done)
# [57/361] Fetching: ['big box retail', 'supermarket stocks', 'grocery stocks', 'beverage companies', 'food manufacturers']
# [58/361] Skipping (already done)
# [59/361] Skipping (already done)
# [60/361] Fetching: ['recession stocks', 'defensive sector', 'consumer spending slowdown', 'store brands', 'kimberly clark stock']
# [61/361] Skipping (already done)
# [62/361] Skipping (already done)
# [63/361] Fetching: ['organic growth', 'inventory buildup', 'margin pressure', 'volume decline', 'tobacco stocks']
# [64/361] Fetching: ['personal care stocks', 'beverage stocks', 'consumer defensive', 'digital transformation', 'beverage industry']
# [65/361] Fetching: ['inelastic demand', 'crispr stocks', 'earnings biotech', 'pipeline drugs', 'cro stocks']
# [66/361] Fetching: ['blockbuster drug', 'health insurers', 'managed care', 'vaccine stocks', 'rare disease']
# [67/361] Fetching: ['oncology drugs', 'eli lilly stock', 'robotic surgery', 'telehealth stocks', 'digital health']
# [68/361] Skipping (already done)
# [69/361] Fetching: ['opioid litigation', 'drug pricing', 'pbm reform', 'ai healthcare', 'novo nordisk stock']
# [70/361] Fetching: ['unitedhealth stock', 'medical robotics', 'obesity drug', 'genomics stocks', 'medicare stocks']
# [71/361] Fetching: ['healthcare reform', 'aging population', 'med tech', 'mental health', 'ai diagnostics']
# [72/361] Skipping (already done)
# [73/361] Fetching: ['health etf', 'drug approval', 'health insurance', 'healthcare reits', 'cro services']
# [74/361] Fetching: ['phase 3 trial', 'medical diagnostics', 'contract research', 'alzheimer’s drugs', 'patent expiry']
# [75/361] Fetching: ['medicare advantage', 'precision medicine', 'ai drug discovery', 'cancer drugs', 'consumer retail']
#   ✓ checkpoint saved at batch 75
# [76/361] Fetching: ['flight to quality', 'safety rotation', 'tariff mitigation', 'healthier options', 'zyn pouches']
# [77/361] Fetching: ['smoke-free future', 'alcohol reset', 'weight-loss drugs', 'food staples', 'consumer necessities']
# [78/361] Fetching: ['earnings stability', 'great rotation', 'safety trade', 'food distributors', 'retail pharmacy']
# [79/361] Fetching: ['alcohol stocks', 'soft drink stocks', 'dividend kings', 'non-discretionary spending', 'defensive yield']
# [80/361] Fetching: ['staple essentials', 'inflation resistant', 'profit margins', 'drug retail', 'noncyclical stocks']
# [81/361] Skipping (already done)
# [82/361] Fetching: ['weight loss drugs', 'glp-1 drugs', 'generic drugs', 'patent cliff', 'drug pipeline']
# [83/361] Skipping (already done)
# [84/361] Skipping (already done)
# [85/361] Fetching: ['defensive allocation', 'market rotation', 'pet food', 'hyperinflation protection', 'cleaning supplies']
# [86/361] Skipping (already done)
# [87/361] Fetching: ['smart meters', 'smr nuclear', 'infrastructure spend', 'multi utilities', 'climate change']
# [88/361] Fetching: ['carbon footprint', 'esg investing', 'water conservation', 'mortgage reit', 'water bill']
# [89/361] Skipping (already done)
# [90/361] Fetching: ['hydrogen power', 'electricity prices', 'regulated utilities', 'data center demand', 'ai power']
# [91/361] Fetching: ['heat pump', 'office reit', 'retail reit', 'industrial reit', 'property dividends']
# [92/361] Skipping (already done)
# [93/361] Fetching: ['office vacancy', 'rental income', 'cap rates', 'property valuations', 'housing downturn']
# [94/361] Skipping (already done)
# [95/361] Fetching: ['realty income', 'real estate etf', 'warehouse reit', 'apartment reit', 'self storage reit']
# [96/361] Fetching: ['healthcare reit', 'data center reit', 'public utilities', 'homebuilder stocks', 'offshore wind']
# [97/361] Skipping (already done)
# [98/361] Fetching: ['renewable integration', 'ev charging', 'capacity market', 'water utility', 'nuclear utility']
# [99/361] Skipping (already done)
# [100/361] Skipping (already done)
# [101/361] Fetching: ['utility dividends', 'renewable utilities', 'gas utilities', 'dividend utility', 'independent power producers']
# [102/361] Fetching: ['rate base', 'utility etf', 'ai power demand', 'carbon neutral', 'electricity bill']
# [103/361] Fetching: ['consolidated edison', 'dominion energy', 'southern company', 'nextera energy', 'duke energy']
# [104/361] Fetching: ['utility monopoly', 'electric rates', 'gas utility', 'baseload power', 'electricity demand']
# [105/361] Fetching: ['power outage', 'utility bonds', 'rate hike utility', 'wind power', 'electricity rates']
# [106/361] Fetching: ['electric utility', 'rate hike utilities', 'utility regulation', 'utility infrastructure', 'wind power stocks']
# [107/361] Skipping (already done)
# [108/361] Fetching: ['passive income', 'real estate etfs', 'property management', 'logistics real estate', 'office stocks']
# [109/361] Fetching: ['cell towers', 'commercial property', 'equity reit', 'residential property', 'distressed assets']
# [110/361] Fetching: ['net operating income', 'luxury housing', 'ffo growth', 'eviction moratorium', 'construction starts']
# [111/361] Fetching: ['home builder', 'foreclosure rate', 'real estate crowdfunding', 'self-storage reit', 'mortgage default']
# [112/361] Skipping (already done)
# [113/361] Skipping (already done)
# [114/361] Fetching: ['price of gold', 'great depression', 'distressed property', 'affordable housing', 'suburban migration']
# [115/361] Skipping (already done)
# [116/361] Fetching: ['build to rent', 'life sciences real estate', 'single family rental', 'reit dividends', 'home equity']
# [117/361] Skipping (already done)
# [118/361] Fetching: ['real estate returns', 'interest rates housing', 'real estate rally', 'cre debt', 'property development']
# [119/361] Skipping (already done)
# [120/361] Fetching: ['real estate dividend', 'property stocks', 'student housing', 'logistics warehouses', 'sunbelt housing']
# [121/361] Fetching: ['property bubble', 'property dividend', 'funds from operations', 'net lease reit', 'hotel reit']
# [122/361] Fetching: ['residential real estate', 'real estate downturn', 'student housing reit', 'life science reit', 'logistics warehouse']
# [123/361] Fetching: ['equity reits', 'ev charging grid', 'self storage', 'triple net', 'housing demand']
# [124/361] Fetching: ['real estate fund', 'retail vacancy', 'housing supply', 'real estate investing', 'home builders']
# [125/361] Fetching: ['property tax', 'rent prices', 'home sales', 'senior housing', 'landlord stocks']
#   ✓ checkpoint saved at batch 125
# [126/361] Skipping (already done)
# [127/361] Skipping (already done)
# [128/361] Skipping (already done)
# [129/361] Fetching: ['wind farm utility', 'metaverse platforms', 'ott platforms', 'podcast advertising', 'esports stocks']
# [130/361] Fetching: ['online advertising', 'ad revenue', 'data usage', 'arpu telecom', 'subscriber growth']
# [131/361] Skipping (already done)
# [132/361] Fetching: ['5g rollout', 'wireless carriers', 'cord cutting', 'digital advertising', 'advertising stocks']
# [133/361] Fetching: ['telecom stocks', 'social media stocks', 'digital security', 'satellite internet', 'pay tv']
# [134/361] Fetching: ['media earnings', 'telecom earnings', '5g network', 'metaverse platform', 'sports broadcasting']
# [135/361] Fetching: ['subscriber churn', 'ott platform', 'connected tv', 'ad targeting', 'cell tower reit']
# [136/361] Skipping (already done)
# [137/361] Skipping (already done)
# [138/361] Skipping (already done)
# [139/361] Fetching: ['networking gear', 'software sector', 'semiconductor chips', 'cyber security', 'system integration']
# [140/361] Skipping (already done)
# [141/361] Fetching: ['application software', 'semiconductor stock', 'apple iphone', 'tech stock', 'semiconductor etf']
# [142/361] Skipping (already done)
# [143/361] Fetching: ['silicon valley', 'gpu stock', 'software stock', 'iphone sales', 'software earnings']
# [144/361] Skipping (already done)
# [145/361] Skipping (already done)
# [146/361] Fetching: ['graphics cards', 'system software', 'genative ai', 'serverless computing', 'operating systems']
# [147/361] Skipping (already done)
# [148/361] Fetching: ['tech sovereignty', 'systems software', 'optical networking', 'digital twins', 'compute demand']
# [149/361] Skipping (already done)
# [150/361] Skipping (already done)
# [151/361] Fetching: ['fast channels', 'dtc streaming', 'content library', 'ai search', 'ai agents']
# [152/361] Fetching: ['content streaming', '6g network', 'wireless data', 'netflix ads', 'streaming service']
# [153/361] Fetching: ['media conglomerate', 'live events', 'internet service', 'content creator', 'ar vr']
# [154/361] Fetching: ['ad spending', 'wireless service', 'video games', 'tiktok trends', 'paramount plus']
# [155/361] Skipping (already done)
# [156/361] Fetching: ['nuclear power plant', 'clean energy utility', 'renewable utility', 'grid infrastructure', 'public utility commission']
# [157/361] Fetching: ['rate hike approval', 'rate case', 'utility earnings', 'utility dividend', 'regulated utility']
# [158/361] Skipping (already done)
# [159/361] Skipping (already done)
# [160/361] Fetching: ['game streaming', 'ai gaming', 'online dating', 'instagram ads', 'gta 6']
# [161/361] Fetching: ['google search', 'tiktok ban', 'influencer economy', 'podcast revenue', 'media merger']
# [162/361] Skipping (already done)
# [163/361] Fetching: ['youtube ads', 'podcasting stocks', 'content spending', 'monthly active users', 'user growth']
# [164/361] Fetching: ['advertising slowdown', 'online video', 'cable providers', 'entertainment stocks', 'broadband stocks']
# [165/361] Fetching: ['platform moderation', 'mobile monetization', 'telecom spectrum', 'data privacy', '5g spectrum']
# [166/361] Fetching: ['augmented reality', 'pinterest stock', 'telecom dividend', 'game development', 'fiber optic']
# [167/361] Fetching: ['facebook stock', 'disney plus', 'broadband internet', 'search advertising', 'cable cutting']
# [168/361] Fetching: ['twitter stock', 'news paywall', 'activision blizzard', 'digital ads', 'platform monetization']
# [169/361] Fetching: ['cable tv', 'programmatic ads', 'streaming subscribers', 'interactive media', 'gaming media']
# [170/361] Skipping (already done)
# [171/361] Fetching: ['media consolidation', 'snap stock', 'experiential travel', 'discount retailer', 'private label']
# [172/361] Skipping (already done)
# [173/361] Skipping (already done)
# [174/361] Skipping (already done)
# [175/361] Skipping (already done)
# [176/361] Fetching: ['oil well', 'midstream energy', 'gas station', 'exxonmobil stock', 'data centers']
# [177/361] Fetching: ['energy etfs', 'oil dividends', 'refining margin', 'energy security', 'blue hydrogen']
# [178/361] Skipping (already done)
# [179/361] Skipping (already done)
# [180/361] Skipping (already done)
# [181/361] Skipping (already done)
# [182/361] Fetching: ['lng exports', 'pipeline stocks', 'shale oil', 'opec news', 'energy supply']
# [183/361] Skipping (already done)
# [184/361] Fetching: ['frac sand', 'oil rig', 'energy earnings', 'natural gas', 'energy index']
# [185/361] Skipping (already done)
# [186/361] Skipping (already done)
# [187/361] Skipping (already done)
# [188/361] Fetching: ['wti crude', 'carbon capture', 'clean energy', 'refining margins', 'oil futures']
# [189/361] Fetching: ['oil supply', 'rig count', 'offshore drilling', 'oil drilling', 'gas prices']
# [190/361] Fetching: ['drilling permits', 'refinery stocks', 'power generation', 'nuclear power', 'grid reliability']
# [191/361] Skipping (already done)
# [192/361] Fetching: ['glass manufacturing', 'paper and packaging', 'cement industry', 'lithium mining', 'silver price']
# [193/361] Fetching: ['gold mining', 'coal price', 'commodity chemicals', 'aluminum price', 'steel industry']
# [194/361] Fetching: ['polymer resins', 'recycling metals', 'mineral extraction', 'raw materials', 'building materials']
# [195/361] Skipping (already done)
# [196/361] Fetching: ['potash fertilizer', 'gold etf', 'packaging stocks', 'paint stocks', 'specialty chemicals']
# [197/361] Skipping (already done)
# [198/361] Fetching: ['chemical stocks', 'fertilizer stocks', 'aluminum futures', 'steel tariffs', 'lithium stocks']
# [199/361] Fetching: ['chemical producers', 'commodity futures', 'material sector etf', 'industrial materials', 'base metals']
# [200/361] Fetching: ['timberland investments', 'phosphate fertilizer', 'gold mining stocks', 'energy stocks', 'copper shortage']
#   ✓ checkpoint saved at batch 200
# [201/361] Fetching: ['materials etfs', 'nuclear renaissance', 'brent oil', 'strategic reserve', 'power grid']
# [202/361] Skipping (already done)
# [203/361] Fetching: ['battery metals', 'small modular reactors', 'grid modernization', 'data center power', 'battery storage']
# [204/361] Skipping (already done)
# [205/361] Fetching: ['power demand', 'ai energy demand', 'electricity bills', 'u.s. shale', 'rare earths']
# [206/361] Fetching: ['plastic resin', 'green chemicals', 'battery materials', 'tariffs metals', 'supply chain metals']
# [207/361] Skipping (already done)
# [208/361] Fetching: ['mining jobs', 'material stocks', 'precious metals', 'carbon fiber', 'agricultural chemicals']
# [209/361] Fetching: ['plastic resins', 'social commerce', 'packaging materials', 'forest products', 'iron ore']
# [210/361] Fetching: ['mining stocks', 'steel demand', 'materials sector', 'manufacturing pmi', 'real estate']
# [211/361] Fetching: ['bond yield', 'quantitative tightening', 'market turmoil', 'capital flight', 'short selling']
# [212/361] Skipping (already done)
# [213/361] Fetching: ['recession fear', 'stock sell-off', 'housing crash', 'currency crisis', 'capital controls']
# [214/361] Fetching: ['equity selloff', 'bond selloff', 'rating downgrade', 'debt default', 'systemic risk']
# [215/361] Fetching: ['stock plunge', 'market panic', 'financial contagion', 'stock market', 'gold price']
# [216/361] Fetching: ['safe haven', 'inflation risk', 'economic uncertainty', 'default risk', 'liquidity crunch']
# [217/361] Fetching: ['recession risk', 'quantitative easing', 'trade war', 'stock downgrade', 'financial meltdown']
# [218/361] Fetching: ['bond crash', 'market meltdown', 'market bottom', 'financial panic', 'stock liquidation']
# [219/361] Fetching: ['market fear', 'panic selling', 'stock bottom', 'sell stocks', 'wealth destruction']
# [220/361] Skipping (already done)
# [221/361] Fetching: ['stock correction', 'yield curve inversion', 'bond yield spike', 'stock volatility', 'market volatility']
# [222/361] Fetching: ['margin call', 'liquidity crisis', 'stock bubble', 'bank collapse', 'sovereign default']
# [223/361] Fetching: ['debt crisis', 'credit crisis', 'market selloff', 'stock selloff', 'economic downturn']
# [224/361] Fetching: ['financial crisis', 'bear market', 'market crash', 'bank failure', 'asset bubble']
# [225/361] Fetching: ['credit downgrade', 'inflation spike', 'inverted yield curve', 'yield inversion', 'vix index']
#   ✓ checkpoint saved at batch 225
# [226/361] Fetching: ['bank run', 'banking crisis', 'economic crisis', 'dividend cut', 'earnings warning']
# [227/361] Fetching: ['unemployment rate', 'junk bonds', 'credit spread', 'interest rates', 'bond yields']
# [228/361] Fetching: ['yield curve', 'corporate default', 'credit crunch', 'market correction', 'stock crash']
# [229/361] Fetching: ['corporate bankruptcy', 'rate cut', 'rate hike', 'asset devaluation', 'market contagion']
# [230/361] Fetching: ['bankruptcy filing', 'financial distress', 'economic stimulus', 'prime rate', 'balance of trade']
# [231/361] Fetching: ['portfolio diversification', 'gold prices', 'oil prices', 'retail sales', 'risk appetite']
# [232/361] Fetching: ['equity markets', 'stock rally', 'capital markets', 'portfolio risk', 'economic forecast']
# [233/361] Fetching: ['stock valuation', 'currency devaluation', 'market rally', 'dividend yield', 'capital gains']
# [234/361] Fetching: ['purchasing power', 'balance sheet', 'interest hike', 'mutual fund', 'crude oil']
# [235/361] Fetching: ['treasury bonds', 'equity risk', 'market liquidity', 'oil price', 'economic indicators']
# [236/361] Fetching: ['manufacturing output', 'price index', 'exchange rates', 'asset prices', 'stock prices']
# [237/361] Fetching: ['consumer spending', 'commodity prices', 'hedge funds', 'initial public', 'purchasing managers']
# [238/361] Fetching: ['consumer sentiment', 'mutual funds', 'mortgage rates', 'asset allocation', 'consumer price']
# [239/361] Fetching: ['treasury bills', 'stock buyback', 'credit rating', 'foreign investment', 'hedge fund']
# [240/361] Fetching: ['market outlook', 'treasury yields', 'fiscal policy', 'monetary policy', 'federal reserve']
# [241/361] Fetching: ['fiscal cliff', 'stock drop', 'financial stress', 'bearish signal', 'inflation rate']
# [242/361] Fetching: ['bull market', 'housing bubble', 'market bubble', 'sovereign debt', 'debt ceiling']
# [243/361] Fetching: ['inverted yield', 'financial turmoil', 'risk off', 'quant tightening', 'black monday']
# [244/361] Fetching: ['economic depression', 'black swan', 's&p 500', 'dow jones', 'bond market']
# [245/361] Fetching: ['earnings report', 'dollar index', 'risk premium', 'capital flows', 'money supply']
# [246/361] Fetching: ['central bank', 'corporate profits', 'economic outlook', 'currency market', 'credit risk']
# [247/361] Fetching: ['equity market', 'corporate earnings', 'corporate debt', 'earnings season', 'exchange rate']
# [248/361] Fetching: ['national debt', 'budget deficit', 'trade deficit', 'housing market', 'consumer confidence']
# [249/361] Fetching: ['economic growth', 'business cycle', 'mining etf', 'social security office', 'steel price']
# [250/361] Fetching: ['clean tech', 'trucking industry', 'robot stocks', 'rail transportation', 'professional services']
#   ✓ checkpoint saved at batch 250
# [251/361] Fetching: ['building products', 'hvac systems', 'gas turbines', 'humanoid robots', 'agentic ai']
# [252/361] Fetching: ['farm machinery', 'heavy trucks', 'construction machinery', 'marine ports', 'commercial jets']
# [253/361] Fetching: ['military drones', 'advanced manufacturing', 'economic security', 'rail transport', 'marine shipping']
# [254/361] Fetching: ['waste management stocks', 'sustainable aviation', 'space infrastructure', 'industrial conglomerates', 'commercial services']
# [255/361] Fetching: ['hotel stocks', 'cruise stocks', 'travel demand', 'housing starts', 'tesla stock']
# [256/361] Fetching: ['ev stocks', 'electric vehicles', 'auto sales', 'luxury retail', 'luxury brands']
# [257/361] Fetching: ['military spending', 'cyber monday', 'holiday sales', 'online retail', 'retail stocks']
# [258/361] Fetching: ['consumer discretionary', 'water treatment', 'power transmission', 'smart grid', 'last-mile delivery']
# [259/361] Fetching: ['industrial ai', 'smart factory', 'black friday', 'air travel demand', 'deere stock']
# [260/361] Fetching: ['space stocks', 'air freight', 'freight rail', 'union pacific', 'lockheed martin']
# [261/361] Fetching: ['defense contractor', 'waste management', 'hvac industry', 'renewable infrastructure', 'freight demand']
# [262/361] Fetching: ['caterpillar stock', 'drone stocks', 'military contracts', 'boeing stock', 'power infrastructure']
# [263/361] Fetching: ['equipment leasing', 'robotics stocks', 'shipping rates', 'freight volumes', 'rail stocks']
# [264/361] Fetching: ['heavy machinery', 'defense contracts', 'commercial aviation', 'airbus orders', 'restaurant stocks']
# [265/361] Fetching: ['defense etf', 'war stocks', 'rail freight', 'air traffic', 'honeywell stock']
# [266/361] Fetching: ['industrial output', 'lithium price', 'ups stock', 'waste management stock', 'supply chain stocks']
# [267/361] Fetching: ['reshoring stocks', 'manufacturing stocks', 'xli etf', 'raytheon stock', 'weapons stocks']
# [268/361] Fetching: ['missile defense', 'trucking stocks', 'infrastructure stocks', 'military budget', 'cargo demand']
# [269/361] Fetching: ['industrials stocks', 'smart manufacturing', 'pentagon budget', 'weapons manufacturer', 'durable goods']
# [270/361] Fetching: ['fast food', 'streaming services', 'theme parks', 'hotel bookings', 'leisure products']
# [271/361] Fetching: ['household durables', 'apparel retail', 'luxury watches', 'discretionary income', 'k-shaped recovery']
# [272/361] Fetching: ['restaurant spending', 'cruise lines', 'e-commerce trends', 'direct to consumer', 'xly etf']
# [273/361] Fetching: ['home depot', 'discretionary stocks', 'furniture sales', 'netflix stock', 'streaming wars']
# [274/361] Fetching: ['trade down', 'dine out', 'experiential retail', 'revenge spending', 'subscription box']
# [275/361] Fetching: ['e-commerce stocks', 'vehicle sales', 'value retail', 'auto parts', 'retail media']
#   ✓ checkpoint saved at batch 275
# [276/361] Fetching: ['casinos gaming', 'hotels resorts', 'consumer services', 'casual dining', 'automobile stocks']
# [277/361] Fetching: ['discount stores', 'consumer cyclical', 'discount retailers', 'value shopping', 'automobile manufacturers']
# [278/361] Fetching: ['consumer bifurcation', 'broadline retail', 'cyclical stocks', 'personalized retail', 'experience economy']
# [279/361] Fetching: ['disposable income', 'travel services', 'leisure facilities', 'specialty retail', 'internet retail']
# [280/361] Fetching: ['consumer electronics', 'k-shaped economy', 'smart factories', 'leisure spending', 'resale market']
# [281/361] Fetching: ['booking holdings', 'department stores', 'apparel brands', 'luxury goods', 'home improvement']
# [282/361] Fetching: ['casino stocks', 'streaming stocks', 'black friday sales', 'luxury spending', 'luxury stocks']
# [283/361] Fetching: ['leisure stocks', 'booking stocks', "mcdonald's stock", 'starbucks stock', 'home depot stock']
# [284/361] Fetching: ['ecommerce stocks', 'nike stock', 'amazon stock', 'footwear brands', 'apparel stocks']
# [285/361] Fetching: ['sports betting', 'gaming stocks', 'chipotle stock', 'home furnishings', 'buy now pay later']
# [286/361] Fetching: ['auto stocks', 'influencer marketing', 'brand loyalty', 'subscription services', 'holiday spending']
# [287/361] Fetching: ['disney stock', 'fast fashion', 'online shopping', 'discretionary spending', 'retail sales data']
# [288/361] Fetching: ['discretionary earnings', 'footwear stocks', 'china consumer demand', 'automotive stocks', 'home improvement stocks']
# [289/361] Fetching: ['brick and mortar', 'retail earnings', 'media stocks', 'fast food stocks', 'restaurants stocks']
# [290/361] Fetching: ['casinos stocks', 'airlines stocks', 'travel stocks', 'used car prices', 'backlog growth']
# [291/361] Fetching: ['fedex stock', 'industrial machinery', 'cargo shipping', 'aluminum stocks', 'hard assets']
# [292/361] Fetching: ['manufacturing index', 'ism manufacturing', 'backlog orders', 'lumber prices', 'automation stocks']
# [293/361] Fetching: ['commercial aircraft', 'warehouse automation', 'freight rates', 'circular economy', 'steel prices']
# [294/361] Fetching: ['industrial production', 'supply chain', 'platinum group', 'nickel supply', 'ev manufacturing']
# [295/361] Fetching: ['electrical equipment', 'resource nationalism', 'semiconductor equipment', 'paper products', 'defense budget']
# [296/361] Fetching: ['factory orders', 'freight stocks', 'aircraft orders', 'industrial earnings', 'aluminum deficit']
# [297/361] Fetching: ['fertilizer prices', 'infrastructure bill', 'industrial stocks', 'silver rally', 'mining m&a']
# [298/361] Fetching: ['industrials sector', 'aerospace defense', 'airlines stock', 'railroad stocks', 'container packaging']
# [299/361] Fetching: ['lumber futures', 'cement prices', 'xlb etf', 'shipping stocks', 'basic materials']
# [300/361] Fetching: ['materials stocks', 'logistics stocks', 'construction stocks', 'engineering firms', 'machinery stocks']
#   ✓ checkpoint saved at batch 300
# [301/361] Fetching: ['chemical industry', 'defense contractors', 'defense spending', 'potash supply', 'engineering services']
# [302/361] Fetching: ['airline stocks', 'resource scarcity', 'steel mills', 'defense stocks', 'air cargo']
# [303/361] Fetching: ['steel stocks', 'order backlog', 'silicon wafers', 'palladium price', 'cobalt price']
# [304/361] Fetching: ['nickel mining', 'zinc mining', 'sustainable packaging', 'potash price', 'copper mining']
# [305/361] Fetching: ['silver mining', 'graphite mining', 'fertilizer price', 'timber prices', 'factory output']
# [306/361] Fetching: ['rare earth', 'capital goods', 'infrastructure spending', 'construction equipment', 'inflation hedge']
# [307/361] Fetching: ['lithium demand', 'transport stocks', 'public works', 'commercial aerospace', 'government contracts']
# [308/361] Fetching: ['industrial automation', 'paper packaging', 'industrial metals', 'material recycling', 'graphite demand']
# [309/361] Fetching: ['water stress', 'metals mining', 'copper supply', 'aerospace stocks', 'industrial etf']
# [310/361] Fetching: ['heavy equipment', 'industrial gases', 'copper stocks', 'green steel', 'industrial robotics']
# [311/361] Fetching: ['uranium price', 'silver etf', 'lumber price', 'commodity supercycle', 'green metals']
# [312/361] Fetching: ['factory automation', 'uranium bull', 'noi', 'faang', 'athleisure']
# [313/361] Fetching: ['citigroup', 'metaverse', 'devaluation', 'gpu', 'microchip']
# [314/361] Fetching: ['software', 'automakers', 'semiconductor', 'vnq', 'prologis']
# [315/361] Fetching: ['saas', 'jpmorgan', 'forestry', 'packaging', 'fdic']
# [316/361] Fetching: ['titanium', 'shrinkflation', 'ffo', 'affo', 'fertilizer']
# [317/361] Fetching: ['aggregates', 'coal', 'sand', 'poverty', 'quarrying']
# [318/361] Fetching: ['phosphate', 'staycation', 'silica', 'hyperinflation', 'clay']
# [319/361] Fetching: ['refinancing', 'insurance', 'direct-to-consumer', 'refinance', 'brokerage']
# [320/361] Fetching: ['gaming', 'casinos', 'redfin', 'zillow', 'premiumization']
# [321/361] Fetching: ['lumber', 'multifamily', 'stagflation', 'restaurants', 'resorts']
# [322/361] Fetching: ['hotels', 'banking', 'volatility', 'textiles', 'palladium']
# [323/361] Fetching: ['unemployed', 'benefits', 'default', 'recession', 'savings']
# [324/361] Fetching: ['donation', 'expense', 'capitalization', 'bankrupt', 'charity']
# [325/361] Fetching: ['frugal', 'crisis', 'economy', 'depression', 'neobank']
#   ✓ checkpoint saved at batch 325
# [326/361] Fetching: ['fintech', 'vix', 'footwear', 'bankruptcy', 'marketplunge']
# [327/361] Fetching: ['economicslowdown', 'reits', 'proptech', 'inversion', 'semiconductors']
# [328/361] Fetching: ['inflation', 'deflation', 'nearshoring', 'currencycrash', 'landlord']
# [329/361] Fetching: ['foreclosure', 'reit', 'multi-utilities', 'uranium', 'over-the-top']
# [330/361] Fetching: ['vaccines', 'medicare', 'medicaid', 'raytheon', 'therapeutics']
# [331/361] Fetching: ['glp-1', 'telecommunication', 'e-sports', 'mvno', 'pharmaceutical']
# [332/361] Fetching: ['pay-per-click', 'genomics', 'spotify', 'comcast', 'podcasting']
# [333/361] Fetching: ['ozempic', '5g', '6g', 'biopharma', 'engineering']
# [334/361] Fetching: ['infrastructure', 'construction', 'telecommunications', 'machinery', 'crispr']
# [335/361] Fetching: ['rearmament', 'wireless', 'telecom', 'publishing', 'movies']
# [336/361] Fetching: ['entertainment', 'broadcasting', 'advertising', 'podcast', 'bioengineering']
# [337/361] Fetching: ['oncology', 'tiktok', 'etf', 'alphabet', 'oil']
# [338/361] Fetching: ['exxon', 'telemedicine', 'downstream', 'schlumberger', 'halliburton']
# [339/361] Fetching: ['upstream', 'netflix', 'streaming', 'esports', 'pharmaceuticals']
# [340/361] Fetching: ['pipelines', 'broadband', 'biotech', 'arpu', 'petrochemicals']
# [341/361] Fetching: ['refineries', 'disney+', 'xle', 'refinery', 'hospitals']
#   Attempt 1/3 failed — The request failed: Google returned a response with code 429. Retrying in 16.5s
#   Attempt 2/3 failed — The request failed: Google returned a response with code 429. Retrying in 31.6s
# [342/361] Fetching: ['fracking', 'lng', 'reshoring', 'neurotechnology', 'youtube']
# [343/361] Fetching: ['onshoring', 'opec', 'chevron', 'ad-supported', 'pay-per-view']
# [344/361] Fetching: ['conocophillips', 'midstream', 'diagnostics', 'biologics', 'bio-manufacturing']
# [345/361] Fetching: ['meta', 'dividend', 'robotics', 'derivative', 'paper']
# [346/361] Fetching: ['nasdaq', 'potash', 'zinc', 'liquidity', 'cpi']
# [347/361] Fetching: ['ppi', 'biotechnology', 'foundry', 'nickel', 'banks']
# [348/361] Fetching: ['logistics', 'lithium', 'ipo', 'silver', 'microchips']
# [349/361] Fetching: ['beverages', 'manufacturing', 'defense', 'glass', 'capitulation']
# [350/361] Fetching: ['microgrid', 'api', 'metals', 'bioeconomy', 'desalination']
#   ✓ checkpoint saved at batch 350
# [351/361] Fetching: ['graphite', 'bearish', 'recycling', 'smelting', 'exploration']
# [352/361] Fetching: ['hypermarkets', 'fertilizers', 'paints', 'gdp', 'aerospace']
# [353/361] Fetching: ['tapering', 'gold', 'copper', 'aluminum', 'wti']
# [354/361] Fetching: ['hydropower', 'automation', 'electrification', 'biosimilars', 'telehealth']
# [355/361] Fetching: ['trucking', 'decarbonization', 'cryptocurrency', 'gpus', 'immunotherapy']
# [356/361] Fetching: ['smartphones', 'reinsurance', 'computing', 're-industrialization', 'dividends']
# [357/361] Fetching: ['commodities', 'shales', 'hyperscaler', 'airlines', 'photonics']
# [358/361] Fetching: ['devops', 'chemicals', 'xlu', 'unemployment', 'earnings']
# [359/361] Fetching: ['steel', 'e-commerce', 'mining', 'currency', 'hardware']
# [360/361] Fetching: ['materials', 'networking', 'tightening', 'transportation', 'warehousing']
# [361/361] Fetching: ['stimulus', 'railroads', 'outsourcing', 'cement']
#
# Started with : 1804
# Survived     : 1450
# Dropped      : 356
#                    keyword  zero_pct  mean_interest
# 0                home care       0.0          92.87
# 1                      oil       0.0          92.85
# 2         medical supplies       0.0          92.30
# 3              diagnostics       0.0          92.00
# 4                    steel       0.0          91.83
# 5                insurance       0.0          91.02
# 6   real estate investment       0.0          90.32
# 7          heavy equipment       0.0          89.89
# 8                  podcast       0.0          89.64
# 9             credit cards       0.0          89.60
# 10             health care       0.0          89.45
# 11             real estate       0.0          89.32
# 12           google search       0.0          88.91
# 13                 disney+       0.0          88.87
# 14                 youtube       0.0          88.72
# 15             credit card       0.0          88.51
# 16             solar power       0.0          88.49
# 17          medical office       0.0          88.49
# 18      financial services       0.0          88.47
# 19                  silver       0.0          88.43

# %%
survivors_with_category = survivors_df.merge(
    combined_deduped[['keyword', 'category']], 
    on='keyword', 
    how='left'
)

print(survivors_with_category['category'].value_counts())
survivors_with_category.head(20)
# Out:
# category
# Category 4 Communication Servic    138
# Category 4 Materials               135
# Category 4 Industrials             126
# Category 4 Energy                  125
# Category 2                         115
# Category 4 Real Estate             113
# Category 4 Financials              111
# Category 4 Information Technolo    111
# Category 4 Health Care             106
# Category 4 Consumer Staples        105
# Category 3                          97
# Category 4 Consumer Discretiona     90
# Category 4 Utilities                78
# Name: count, dtype: int64
#                    keyword  zero_pct  mean_interest  \
# 0                home care       0.0          92.87
# 1                      oil       0.0          92.85
# 2         medical supplies       0.0          92.30
# 3              diagnostics       0.0          92.00
# 4                    steel       0.0          91.83
# 5                insurance       0.0          91.02
# 6   real estate investment       0.0          90.32
# 7          heavy equipment       0.0          89.89
# 8                  podcast       0.0          89.64
# 9             credit cards       0.0          89.60
# 10             health care       0.0          89.45
# 11             real estate       0.0          89.32
# 12           google search       0.0          88.91
# 13                 disney+       0.0          88.87
# 14                 youtube       0.0          88.72
# 15             credit card       0.0          88.51
# 16             solar power       0.0          88.49
# 17          medical office       0.0          88.49
# 18      financial services       0.0          88.47
# 19                  silver       0.0          88.43
#
#                            category
# 0       Category 4 Consumer Staples
# 1                 Category 4 Energy
# 2            Category 4 Health Care
# 3            Category 4 Health Care
# 4              Category 4 Materials
# 5             Category 4 Financials
# 6            Category 4 Real Estate
# 7            Category 4 Industrials
# 8   Category 4 Communication Servic
# 9             Category 4 Financials
# 10           Category 4 Health Care
# 11                       Category 3
# 12  Category 4 Communication Servic
# 13  Category 4 Communication Servic
# 14  Category 4 Communication Servic
# 15            Category 4 Financials
# 16                Category 4 Energy
# 17           Category 4 Real Estate
# 18            Category 4 Financials
# 19             Category 4 Materials

# %%
import pandas as pd

lm = pd.read_csv('lm_dict_survivors.csv')[['keyword']]
llm = pd.read_csv('llm_survivors.csv')[['keyword']]

print(f"LM survivors: {len(lm)}")
print(f"LLM survivors: {len(llm)}")

# Combine and deduplicate
final = pd.concat([lm, llm]).drop_duplicates(subset='keyword').reset_index(drop=True)

print(f"Total after deduplication: {len(final)}")

final.to_csv('final_keywords.csv', index=False)
print("Saved to final_keywords.csv")
final
# Out:
# LM survivors: 174
# LLM survivors: 1450
# Total after deduplication: 1620
# Saved to final_keywords.csv
#                    keyword
# 0                   broken
# 1                      bad
# 2                  rewards
# 3                    error
# 4                    great
# ...                    ...
# 1615    defense contractor
# 1616    property vacancies
# 1617           office reit
# 1618  currency devaluation
# 1619         shrinkflation
#
# [1620 rows x 1 columns]

# %%
import os
os.path.exists('final_keywords.csv')
# Out:
# True
